# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements **OAuth 1.0A** as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# **pkl** is a Python utility module that does **serialization** to convert any Python object or data structure to a character stream so that it can be saved to the disk and recreated in Python if we need it later.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
#!pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.17.1-py2.py3-none-any.whl (55kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.17.1

# %%
if not os.path.exists('C:/ml/twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('C:/ml/twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('C:/ml/twitter_credentials.pkl','rb'))

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

## use twitter keys from pkl file to create twitter api object in python

# create authentication object
auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

# create twitter api object
twitter_api = twitter.Twitter(auth = auth)

# Nothing to see by displaying twitter_api except that it's now a defined variable
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000000004A52E10>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the **Yahoo! Where On Earth ID**.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
SANDIEGO_LOCAL_WOE_ID = 2487889
PHILLY_LOCAL_WOE_ID = 2471217

# Prefix ID argument in .trends.place() with the underscore for query string parameterization.
#     - Without underscore, twitter package appends the ID value to the URL itself as a special case keyword argument.

# get top 50 trends from various areas via a trend object in JSON
world_trends = twitter_api.trends.place(_id = WORLD_WOE_ID) # = 1
us_trends = twitter_api.trends.place(_id = US_WOE_ID) # = 23424977
sd_trends = twitter_api.trends.place(_id = SANDIEGO_LOCAL_WOE_ID) # = 2487889
philly_trends = twitter_api.trends.place(_id = PHILLY_LOCAL_WOE_ID) # = 2487889


# see top 2 world trends
world_trends[:2]
# Out:
# [{'as_of': '2017-07-25T12:34:56Z',
#   'created_at': '2017-07-25T12:31:20Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#FelizMartes',
#     'promoted_content': None,
#     'query': '%23FelizMartes',
#     'tweet_volume': 19310,
#     'url': 'http://twitter.com/search?q=%23FelizMartes'},
#    {'name': 'Mbappé',
#     'promoted_content': None,
#     'query': 'Mbapp%C3%A9',
#     'tweet_volume': 77402,
#     'url': 'http://twitter.com/search?q=Mbapp%C3%A9'},
#    {'name': '#Barcelona92',
#     'promoted_content': None,
#     'query': '%23Barcelona92',
#     'tweet_volume': 12267,
#     'url': 'http://twitter.com/search?q=%23Barcelona92'},
#    {'name': '#TuesdayThoughts',
#     'promoted_content': None,
#     'query': '%23TuesdayThoughts',
#     'tweet_volume': 22969,
#     'url': 'http://twitter.com/search?q=%23TuesdayThoughts'},
#    {'name': '土用の丑の日',
#     'promoted_content': None,
#     'query': '%E5%9C%9F%E7%94%A8%E3%81%AE%E4%B8%91%E3%81%AE%E6%97%A5',
#     'tweet_volume': 141920,
#     'url': 'http://twitter.com/search?q=%E5%9C%9F%E7%94%A8%E3%81%AE%E4%B8%91%E3%81%AE%E6%97%A5'},
#    {'name': '#25Jul',
#     'promoted_content': None,
#     'query': '%2325Jul',
#     'tweet_volume': 10366,
#     'url': 'http://twitter.com/search?q=%2325Jul'},
#    {'name': '#25TemmuzDünyaKiloVermeGünü',
#     'promoted_content': None,
#     'query': '%2325TemmuzD%C3%BCnyaKiloVermeG%C3%BCn%C3%BC',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%2325TemmuzD%C3%BCnyaKiloVermeG%C3%BCn%C3%BC'},
#    {'name': 'Marcos Alonso',
#     'promoted_content': None,
#     'query': '%22Marcos+Alonso%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Marcos+Alonso%22'},
#    {'name': 'Artur Almeida',
#     'promoted_content': None,
#     'query': '%22Artur+Almeida%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Artur+Almeida%22'},
#    {'name': 'Michael Kors',
#     'promoted_content': None,
#     'query': '%22Michael+Kors%22',
#     'tweet_volume': 18091,
#     'url': 'http://twitter.com/search?q=%22Michael+Kors%22'},
#    {'name': '天神祭',
#     'promoted_content': None,
#     'query': '%E5%A4%A9%E7%A5%9E%E7%A5%AD',
#     'tweet_volume': 48268,
#     'url': 'http://twitter.com/search?q=%E5%A4%A9%E7%A5%9E%E7%A5%AD'},
#    {'name': 'Melilla',
#     'promoted_content': None,
#     'query': 'Melilla',
#     'tweet_volume': 10227,
#     'url': 'http://twitter.com/search?q=Melilla'},
#    {'name': 'SefaÖzcan Kader',
#     'promoted_content': None,
#     'query': '%22Sefa%C3%96zcan+Kader%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Sefa%C3%96zcan+Kader%22'},
#    {'name': '横浜優勝',
#     'promoted_content': None,
#     'query': '%E6%A8%AA%E6%B5%9C%E5%84%AA%E5%8B%9D',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%E6%A8%AA%E6%B5%9C%E5%84%AA%E5%8B%9D'},
#    {'name': '초동 60만',
#     'promoted_content': None,
#     'query': '%22%EC%B4%88%EB%8F%99+60%EB%A7%8C%22',
#     'tweet_volume': 21789,
#     'url': 'http://twitter.com/search?q=%22%EC%B4%88%EB%8F%99+60%EB%A7%8C%22'},
#    {'name': '#علي_سبيل_المزاج',
#     'promoted_content': None,
#     'query': '%23%D8%B9%D9%84%D9%8A_%D8%B3%D8%A8%D9%8A%D9%84_%D8%A7%D9%84%D9%85%D8%B2%D8%A7%D8%AC',
#     'tweet_volume': 53501,
#     'url': 'http://twitter.com/search?q=%23%D8%B9%D9%84%D9%8A_%D8%B3%D8%A8%D9%8A%D9%84_%D8%A7%D9%84%D9%85%D8%B2%D8%A7%D8%AC'},
#    {'name': '#AltınElbiseliAdam',
#     'promoted_content': None,
#     'query': '%23Alt%C4%B1nElbiseliAdam',
#     'tweet_volume': 22256,
#     'url': 'http://twitter.com/search?q=%23Alt%C4%B1nElbiseliAdam'},
#    {'name': '#KılıçdaroğluNeSöyledi',
#     'promoted_content': None,
#     'query': '%23K%C4%B1l%C4%B1%C3%A7daro%C4%9FluNeS%C3%B6yledi',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23K%C4%B1l%C4%B1%C3%A7daro%C4%9FluNeS%C3%B6yledi'},
#    {'name': '#CFCFCB',
#     'promoted_content': None,
#     'query': '%23CFCFCB',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23CFCFCB'},
#    {'name': '#ThingsToAvoidAtAPublicPool',
#     'promoted_content': None,
#     'query': '%23ThingsToAvoidAtAPublicPool',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ThingsToAvoidAtAPublicPool'},
#    {'name': '#VenezuelaVotaEn5Dias',
#     'promoted_content': None,
#     'query': '%23VenezuelaVotaEn5Dias',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23VenezuelaVotaEn5Dias'},
#    {'name': '#افضل_لاعب_امتعك_الموسم_الماضي',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%81%D8%B6%D9%84_%D9%84%D8%A7%D8%B9%D8%A8_%D8%A7%D9%85%D8%AA%D8%B9%D9%83_%D8%A7%D9%84%D9%85%D9%88%D8%B3%D9%85_%D8%A7%D9%84%D9%85%D8%A7%D8%B6%D9%8A',
#     'tweet_volume': 38888,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%81%D8%B6%D9%84_%D9%84%D8%A7%D8%B9%D8%A8_%D8%A7%D9%85%D8%AA%D8%B9%D9%83_%D8%A7%D9%84%D9%85%D9%88%D8%B3%D9%85_%D8%A7%D9%84%D9%85%D8%A7%D8%B6%D9%8A'},
#    {'name': '#ابن_فهد_يجلد_ابن_زايد',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D8%A8%D9%86_%D9%81%D9%87%D8%AF_%D9%8A%D8%AC%D9%84%D8%AF_%D8%A7%D8%A8%D9%86_%D8%B2%D8%A7%D9%8A%D8%AF',
#     'tweet_volume': 42519,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D8%A8%D9%86_%D9%81%D9%87%D8%AF_%D9%8A%D8%AC%D9%84%D8%AF_%D8%A7%D8%A8%D9%86_%D8%B2%D8%A7%D9%8A%D8%AF'},
#    {'name': '#Ccs450',
#     'promoted_content': None,
#     'query': '%23Ccs450',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Ccs450'},
#    {'name': '#DíadeGalicia',
#     'promoted_content': None,
#     'query': '%23D%C3%ADadeGalicia',
#     'tweet_volume': 11128,
#     'url': 'http://twitter.com/search?q=%23D%C3%ADadeGalicia'},
#    {'name': '#NinjaWarriorAU',
#     'promoted_content': None,
#     'query': '%23NinjaWarriorAU',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NinjaWarriorAU'},
#    {'name': '#TongueOutTuesday',
#     'promoted_content': None,
#     'query': '%23TongueOutTuesday',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TongueOutTuesday'},
#    {'name': '#TercaDetremuraSDV',
#     'promoted_content': None,
#     'query': '%23TercaDetremuraSDV',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TercaDetremuraSDV'},
#    {'name': '#قطار_الحرمين',
#     'promoted_content': None,
#     'query': '%23%D9%82%D8%B7%D8%A7%D8%B1_%D8%A7%D9%84%D8%AD%D8%B1%D9%85%D9%8A%D9%86',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D9%82%D8%B7%D8%A7%D8%B1_%D8%A7%D9%84%D8%AD%D8%B1%D9%85%D9%8A%D9%86'},
#    {'name': '#디스패치_도를넘어나대',
#     'promoted_content': None,
#     'query': '%23%EB%94%94%EC%8A%A4%ED%8C%A8%EC%B9%98_%EB%8F%84%EB%A5%BC%EB%84%98%EC%96%B4%EB%82%98%EB%8C%80',
#     'tweet_volume': 24276,
#     'url': 'http://twitter.com/search?q=%23%EB%94%94%EC%8A%A4%ED%8C%A8%EC%B9%98_%EB%8F%84%EB%A5%BC%EB%84%98%EC%96%B4%EB%82%98%EB%8C%80'},
#    {'name': '#BedelliMasayaYatırılıyor',
#     'promoted_content': None,
#     'query': '%23BedelliMasayaYat%C4%B1r%C4%B1l%C4%B1yor',
#     'tweet_volume': 18170,
#     'url': 'http://twitter.com/search?q=%23BedelliMasayaYat%C4%B1r%C4%B1l%C4%B1yor'},
#    {'name': '#برنامج_الرسام',
#     'promoted_content': None,
#     'query': '%23%D8%A8%D8%B1%D9%86%D8%A7%D9%85%D8%AC_%D8%A7%D9%84%D8%B1%D8%B3%D8%A7%D9%85',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%A8%D8%B1%D9%86%D8%A7%D9%85%D8%AC_%D8%A7%D9%84%D8%B1%D8%B3%D8%A7%D9%85'},
#    {'name': '#myhyv',
#     'promoted_content': None,
#     'query': '%23myhyv',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23myhyv'},
#    {'name': '#DiadaPatriaGalega',
#     'promoted_content': None,
#     'query': '%23DiadaPatriaGalega',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23DiadaPatriaGalega'},
#    {'name': '#تركي_يعتدي_علي_سعوديين',
#     'promoted_content': None,
#     'query': '%23%D8%AA%D8%B1%D9%83%D9%8A_%D9%8A%D8%B9%D8%AA%D8%AF%D9%8A_%D8%B9%D9%84%D9%8A_%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%8A%D9%86',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%AA%D8%B1%D9%83%D9%8A_%D9%8A%D8%B9%D8%AA%D8%AF%D9%8A_%D8%B9%D9%84%D9%8A_%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%8A%D9%86'},
#    {'name': '#Fan2IsOverParty',
#     'promoted_content': None,
#     'query': '%23Fan2IsOverParty',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Fan2IsOverParty'},
#    {'name': '#ŞişliyiBatırdınİnönü',
#     'promoted_content': None,
#     'query': '%23%C5%9Ei%C5%9FliyiBat%C4%B1rd%C4%B1n%C4%B0n%C3%B6n%C3%BC',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%C5%9Ei%C5%9FliyiBat%C4%B1rd%C4%B1n%C4%B0n%C3%B6n%C3%BC'},
#    {'name': '#PresidentKovind',
#     'promoted_content': None,
#     'query': '%23PresidentKovind',
#     'tweet_volume': 54390,
#     'url': 'http://twitter.com/search?q=%23PresidentKovind'},
#    {'name': '#SIRE',
#     'promoted_content': None,
#     'query': '%23SIRE',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SIRE'},
#    {'name': '#Halilİnalcık',
#     'promoted_content': None,
#     'query': '%23Halil%C4%B0nalc%C4%B1k',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Halil%C4%B0nalc%C4%B1k'},
#    {'name': '#MyKoreanJagiyaTheReveal',
#     'promoted_content': None,
#     'query': '%23MyKoreanJagiyaTheReveal',
#     'tweet_volume': 18333,
#     'url': 'http://twitter.com/search?q=%23MyKoreanJagiyaTheReveal'},
#    {'name': '#santiagoapostol',
#     'promoted_content': None,
#     'query': '%23santiagoapostol',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23santiagoapostol'},
#    {'name': '#cosasbuenas',
#     'promoted_content': None,
#     'query': '%23cosasbuenas',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23cosasbuenas'},
#    {'name': '#SempreQuisTer',
#     'promoted_content': None,
#     'query': '%23SempreQuisTer',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SempreQuisTer'},
#    {'name': '#NUESTW_If_You',
#     'promoted_content': None,
#     'query': '%23NUESTW_If_You',
#     'tweet_volume': 96252,
#     'url': 'http://twitter.com/search?q=%23NUESTW_If_You'},
#    {'name': '#MardiConseil',
#     'promoted_content': None,
#     'query': '%23MardiConseil',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MardiConseil'},
#    {'name': '#Bignardi',
#     'promoted_content': None,
#     'query': '%23Bignardi',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Bignardi'},
#    {'name': '#マツコの知らない世界',
#     'promoted_content': None,
#     'query': '%23%E3%83%9E%E3%83%84%E3%82%B3%E3%81%AE%E7%9F%A5%E3%82%89%E3%81%AA%E3%81%84%E4%B8%96%E7%95%8C',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%E3%83%9E%E3%83%84%E3%82%B3%E3%81%AE%E7%9F%A5%E3%82%89%E3%81%AA%E3%81%84%E4%B8%96%E7%95%8C'},
#    {'name': '#CHEBAY',
#     'promoted_content': None,
#     'query': '%23CHEBAY',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23CHEBAY'},
#    {'name': '#仰天ニュース',
#     'promoted_content': None,
#     'query': '%23%E4%BB%B0%E5%A4%A9%E3%83%8B%E3%83%A5%E3%83%BC%E3%82%B9',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%E4%BB%B0%E5%A4%A9%E3%83%8B%E3%83%A5%E3%83%BC%E3%82%B9'}]}]

# %% [markdown]
# API responses are in **JSON (JavaScript Object Notation)** format, which is used to transfer data on the web and is roughly equivalent to nested Python lists and dictionaries, or 'more-concise' XML
#
# Top 2 trends as of 7/24/2017, 9:59 AM EST are "#FelizLunes" and "#MondayMotivation"

# %%
# see type of the trends object
print(type(sd_trends),'\n')

# see the keys from the 1st record/object
print(list(sd_trends[0].keys()),'\n')

# see the trend data from the 1st object
print(sd_trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
#
# ['trends', 'as_of', 'created_at', 'locations']
#
# [{'name': '#InsecureHBO', 'url': 'http://twitter.com/search?q=%23InsecureHBO', 'promoted_content': None, 'query': '%23InsecureHBO', 'tweet_volume': 127537}, {'name': '#ElTriEng', 'url': 'http://twitter.com/search?q=%23ElTriEng', 'promoted_content': None, 'query': '%23ElTriEng', 'tweet_volume': None}, {'name': '#WWEBattleground', 'url': 'http://twitter.com/search?q=%23WWEBattleground', 'promoted_content': None, 'query': '%23WWEBattleground', 'tweet_volume': 227952}, {'name': '#NW88JR', 'url': 'http://twitter.com/search?q=%23NW88JR', 'promoted_content': None, 'query': '%23NW88JR', 'tweet_volume': None}, {'name': '#SDCC2017', 'url': 'http://twitter.com/search?q=%23SDCC2017', 'promoted_content': None, 'query': '%23SDCC2017', 'tweet_volume': 102633}, {'name': 'Jared Kushner', 'url': 'http://twitter.com/search?q=%22Jared+Kushner%22', 'promoted_content': None, 'query': '%22Jared+Kushner%22', 'tweet_volume': 88129}, {'name': 'Paint', 'url': 'http://twitter.com/search?q=Paint', 'promoted_content': None, 'query': 'Paint', 'tweet_volume': 85712}, {'name': "Bush's Baked Beans", 'url': 'http://twitter.com/search?q=%22Bush%27s+Baked+Beans%22', 'promoted_content': None, 'query': '%22Bush%27s+Baked+Beans%22', 'tweet_volume': None}, {'name': 'Ray Tensing', 'url': 'http://twitter.com/search?q=%22Ray+Tensing%22', 'promoted_content': None, 'query': '%22Ray+Tensing%22', 'tweet_volume': None}, {'name': 'Rudy Giuliani', 'url': 'http://twitter.com/search?q=%22Rudy+Giuliani%22', 'promoted_content': None, 'query': '%22Rudy+Giuliani%22', 'tweet_volume': None}, {'name': 'Dan Rooney', 'url': 'http://twitter.com/search?q=%22Dan+Rooney%22', 'promoted_content': None, 'query': '%22Dan+Rooney%22', 'tweet_volume': None}, {'name': 'Kent Island', 'url': 'http://twitter.com/search?q=%22Kent+Island%22', 'promoted_content': None, 'query': '%22Kent+Island%22', 'tweet_volume': None}, {'name': 'WR Anquan Boldin', 'url': 'http://twitter.com/search?q=%22WR+Anquan+Boldin%22', 'promoted_content': None, 'query': '%22WR+Anquan+Boldin%22', 'tweet_volume': None}, {'name': 'Foster', 'url': 'http://twitter.com/search?q=Foster', 'promoted_content': None, 'query': 'Foster', 'tweet_volume': 32354}, {'name': 'The Kook', 'url': 'http://twitter.com/search?q=%22The+Kook%22', 'promoted_content': None, 'query': '%22The+Kook%22', 'tweet_volume': None}, {'name': 'Sidney Jones', 'url': 'http://twitter.com/search?q=%22Sidney+Jones%22', 'promoted_content': None, 'query': '%22Sidney+Jones%22', 'tweet_volume': None}, {'name': 'Greg Ward', 'url': 'http://twitter.com/search?q=%22Greg+Ward%22', 'promoted_content': None, 'query': '%22Greg+Ward%22', 'tweet_volume': None}, {'name': 'Interstate Bridge', 'url': 'http://twitter.com/search?q=%22Interstate+Bridge%22', 'promoted_content': None, 'query': '%22Interstate+Bridge%22', 'tweet_volume': None}, {'name': 'Suga Free', 'url': 'http://twitter.com/search?q=%22Suga+Free%22', 'promoted_content': None, 'query': '%22Suga+Free%22', 'tweet_volume': None}, {'name': 'GenX', 'url': 'http://twitter.com/search?q=GenX', 'promoted_content': None, 'query': 'GenX', 'tweet_volume': None}, {'name': 'Alexandre Dumas', 'url': 'http://twitter.com/search?q=%22Alexandre+Dumas%22', 'promoted_content': None, 'query': '%22Alexandre+Dumas%22', 'tweet_volume': None}, {'name': 'Chuck Schumer', 'url': 'http://twitter.com/search?q=%22Chuck+Schumer%22', 'promoted_content': None, 'query': '%22Chuck+Schumer%22', 'tweet_volume': 38447}, {'name': 'Sherrod Brown', 'url': 'http://twitter.com/search?q=%22Sherrod+Brown%22', 'promoted_content': None, 'query': '%22Sherrod+Brown%22', 'tweet_volume': None}, {'name': 'Morning Joe', 'url': 'http://twitter.com/search?q=%22Morning+Joe%22', 'promoted_content': None, 'query': '%22Morning+Joe%22', 'tweet_volume': None}, {'name': 'Santana Row', 'url': 'http://twitter.com/search?q=%22Santana+Row%22', 'promoted_content': None, 'query': '%22Santana+Row%22', 'tweet_volume': None}, {'name': 'Mack Hollins', 'url': 'http://twitter.com/search?q=%22Mack+Hollins% ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

# get a more-formatted version of JSON output with indents for every new level
print((json.dumps(us_trends[:2], indent = 1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#TuesdayThoughts",
#     "url": "http://twitter.com/search?q=%23TuesdayThoughts",
#     "promoted_content": null,
#     "query": "%23TuesdayThoughts",
#     "tweet_volume": 22969
#    },
#    {
#     "name": "#ThingsToAvoidAtAPublicPool",
#     "url": "http://twitter.com/search?q=%23ThingsToAvoidAtAPublicPool",
#     "promoted_content": null,
#     "query": "%23ThingsToAvoidAtAPublicPool",
#     "tweet_volume": null
#    },
#    {
#     "name": "Michael Kors",
#     "url": "http://twitter.com/search?q=%22Michael+Kors%22",
#     "promoted_content": null,
#     "query": "%22Michael+Kors%22",
#     "tweet_volume": 18091
#    },
#    {
#     "name": "#BoyScoutSpeech",
#     "url": "http://twitter.com/search?q=%23BoyScoutSpeech",
#     "promoted_content": null,
#     "query": "%23BoyScoutSpeech",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TravelTuesday",
#     "url": "http://twitter.com/search?q=%23TravelTuesday",
#     "promoted_content": null,
#     "query": "%23TravelTuesday",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mbappe",
#     "url": "http://twitter.com/search?q=Mbappe",
#     "promoted_content": null,
#     "query": "Mbappe",
#     "tweet_volume": 77401
#    },
#    {
#     "name": "Taliban",
#     "url": "http://twitter.com/search?q=Taliban",
#     "promoted_content": null,
#     "query": "Taliban",
#     "tweet_volume": 23042
#    },
#    {
#     "name": "#FelizMartes",
#     "url": "http://twitter.com/search?q=%23FelizMartes",
#     "promoted_content": null,
#     "query": "%23FelizMartes",
#     "tweet_volume": 19310
#    },
#    {
#     "name": "Barron Trump",
#     "url": "http://twitter.com/search?q=%22Barron+Trump%22",
#     "promoted_content": null,
#     "query": "%22Barron+Trump%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Capitol Hill for 2nd",
#     "url": "http://twitter.com/search?q=%22Capitol+Hill+for+2nd%22",
#     "promoted_content": null,
#     "query": "%22Capitol+Hill+for+2nd%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ben Franklin Bridge",
#     "url": "http://twitter.com/search?q=%22Ben+Franklin+Bridge%22",
#     "promoted_content": null,
#     "query": "%22Ben+Franklin+Bridge%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "What to Expect",
#     "url": "http://twitter.com/search?q=%22What+to+Expect%22",
#     "promoted_content": null,
#     "query": "%22What+to+Expect%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gwinnett Co",
#     "url": "http://twitter.com/search?q=%22Gwinnett+Co%22",
#     "promoted_content": null,
#     "query": "%22Gwinnett+Co%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "O God",
#     "url": "http://twitter.com/search?q=%22O+God%22",
#     "promoted_content": null,
#     "query": "%22O+God%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "A.G.",
#     "url": "http://twitter.com/search?q=A.G.",
#     "promoted_content": null,
#     "query": "A.G.",
#     "tweet_volume": 186206
#    },
#    {
#     "name": "HAPPENING TODAY",
#     "url": "http://twitter.com/search?q=%22HAPPENING+TODAY%22",
#     "promoted_content": null,
#     "query": "%22HAPPENING+TODAY%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Yano",
#     "url": "http://twitter.com/search?q=Yano",
#     "promoted_content": null,
#     "query": "Yano",
#     "tweet_volume": null
#    },
#    {
#     "name": "Alice Cooper",
#     "url": "http://twitter.com/search?q=%22Alice+Cooper%22",
#     "promoted_content": null,
#     "query": "%22Alice+Cooper%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Die Young",
#     "url": "http://twitter.com/search?q=%22Die+Young%22",
#     "promoted_content": null,
#     "query": "%22Die+Young%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "23 STEM",
#     "url": "http://twitter.com/search?q=%2223+STEM%22",
#     "promoted_content": null,
#     "query": "%2223+STEM%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Comerica Park",
#     "url": "http://twitter.com/search?q=%22Comerica+Park%22",
#     "promoted_content": null,
#     "query": "%22Comerica+Park%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Luis Fonsi y Daddy Yankee",
#     "url": "http://twitter.com/search?q=%22Luis+Fonsi+y+Daddy+Yankee%22",
#     "promoted_content": null,
#     "query": "%22Luis+Fonsi+y+Daddy+Yankee%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Daily 202",
#     "url": "http://twitter.com/search?q=%22The+Daily+202%22",
#     "promoted_content": null,
#     "query": "%22The+Daily+202%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "House Intel",
#     "url": "http://twitter.com/search?q=%22House+Intel%22",
#     "promoted_content": null,
#     "query": "%22House+Intel%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Justice Dept",
#     "url": "http://twitter.com/search?q=%22Justice+Dept%22",
#     "promoted_content": null,
#     "query": "%22Justice+Dept%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Win A Copy Of The Book",
#     "url": "http://twitter.com/search?q=%22Win+A+Copy+Of+The+Book%22",
#     "promoted_content": null,
#     "query": "%22Win+A+Copy+Of+The+Book%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Attorney General Sessions",
#     "url": "http://twitter.com/search?q=%22Attorney+General+Sessions%22",
#     "promoted_content": null,
#     "query": "%22Attorney+General+Sessions%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MIPmornings",
#     "url": "http://twitter.com/search?q=%23MIPmornings",
#     "promoted_content": null,
#     "query": "%23MIPmornings",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CFCFCB",
#     "url": "http://twitter.com/search?q=%23CFCFCB",
#     "promoted_content": null,
#     "query": "%23CFCFCB",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MyDreamTripWouldBe",
#     "url": "http://twitter.com/search?q=%23MyDreamTripWouldBe",
#     "promoted_content": null,
#     "query": "%23MyDreamTripWouldBe",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Suffield",
#     "url": "http://twitter.com/search?q=%23Suffield",
#     "promoted_content": null,
#     "query": "%23Suffield",
#     "tweet_volume": null
#    },
#    {
#     "name": "#2bittues",
#     "url": "http://twitter.com/search?q=%232bittues",
#     "promoted_content": null,
#     "query": "%232bittues",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WhatILearnedToday",
#     "url": "http://twitter.com/search?q=%23WhatILearnedToday",
#     "promoted_content": null,
#     "query": "%23WhatILearnedToday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#iamup",
#     "url": "http://twitter.com/search?q=%23iamup",
#     "promoted_content": null,
#     "query": "%23iamup",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LiveAtDaybreak",
#     "url": "http://twitter.com/search?q=%23LiveAtDaybreak",
#     "promoted_content": null,
#     "query": "%23LiveAtDaybreak",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PetFoodDrive",
#     "url": "http://twitter.com/search?q=%23PetFoodDrive",
#     "promoted_content": null,
#     "query": "%23PetFoodDrive",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MyIrrationalFearIn4Words",
#     "url": "http://twitter.com/search?q=%23MyIrrationalFearIn4Words",
#     "promoted_content": null,
#     "query": "%23MyIrrationalFearIn4Words",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SSZ1035",
#     "url": "http://twitter.com/search?q=%23SSZ1035",
#     "promoted_content": null,
#     "query": "%23SSZ1035",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CAAFB",
#     "url": "http://twitter.com/search?q=%23CAAFB",
#     "promoted_content": null,
#     "query": "%23CAAFB",
#     "tweet_volume": null
#    },
#    {
#     "name": "#25Jul",
#     "url": "http://twitter.com/search?q=%2325Jul",
#     "promoted_content": null,
#     "query": "%2325Jul",
#     "tweet_volume": 10366
#    },
#    {
#     "name": "#TISL",
#     "url": "http://twitter.com/search?q=%23TISL",
#     "promoted_content": null,
#     "query": "%23TISL",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AtlantaAlive",
#     "url": "http://twitter.com/search?q=%23AtlantaAlive",
#     "promoted_content": null,
#     "query": "%23AtlantaAlive",
#     "tweet_volume": null
#    },
#    {
#     "name": "#markets",
#     "url": "http://twitter.com/search?q=%23markets",
#     "promoted_content": null,
#     "query": "%23markets",
#     "tweet_volume": null
#    },
#    {
#     "name": "#njmorningshow",
#     "url": "http://twitter.com/search?q=%23njmorningshow",
#     "promoted_content": null,
#     "query": "%23njmorningshow",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FreeRightsDefenders",
#     "url": "http://twitter.com/search?q=%23FreeRightsDefenders",
#     "promoted_content": null,
#     "query": "%23FreeRightsDefenders",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NamedMyShark",
#     "url": "http://twitter.com/search?q=%23NamedMyShark",
#     "promoted_content": null,
#     "query": "%23NamedMyShark",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GMRVA",
#     "url": "http://twitter.com/search?q=%23GMRVA",
#     "promoted_content": null,
#     "query": "%23GMRVA",
#     "tweet_volume": null
#    },
#    {
#     "name": "#13NewsNow",
#     "url": "http://twitter.com/search?q=%2313NewsNow",
#     "promoted_content": null,
#     "query": "%2313NewsNow",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RussiaSanctions",
#     "url": "http://twitter.com/search?q=%23RussiaSanctions",
#     "promoted_content": null,
#     "query": "%23RussiaSanctions",
#     "tweet_volume": null
#    },
#    {
#     "name": "#nbc4ny",
#     "url": "http://twitter.com/search?q=%23nbc4ny",
#     "promoted_content": null,
#     "query": "%23nbc4ny",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2017-07-25T12:34:56Z",
#   "created_at": "2017-07-25T12:31:20Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two *sets* of trends
#
# i.e. Find commonalities in the trends from different locations

# %%
# create empty set
trends_set = {}

# from the list value of the 'trends' key from the dictionary in the JSON response, go through each dictionary element w/in
#   the list and get the value from the 'name' key and keep only unique ones
trends_set['world'] = set(trend['name'] for trend in world_trends[0]['trends'])

trends_set['us'] = set(trend['name'] for trend in us_trends[0]['trends'])

trends_set['san diego'] = set(trend['name'] for trend in sd_trends[0]['trends'])

trends_set['philly'] = set(trend['name'] for trend in philly_trends[0]['trends'])

# %%
# join the datasets together and loop through them to get each trend from each set 
for loc in ['world','us','san diego','philly']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# Michael Kors,#TongueOutTuesday,#قطار_الحرمين,#PresidentKovind,#MardiConseil,#DíadeGalicia,#BedelliMasayaYatırılıyor,SefaÖzcan Kader,#برنامج_الرسام,#SIRE,#CHEBAY,#Barcelona92,#AltınElbiseliAdam,#افضل_لاعب_امتعك_الموسم_الماضي,#25Jul,#NinjaWarriorAU,초동 60만,#myhyv,#FelizMartes,#Bignardi,Melilla,Marcos Alonso,#ThingsToAvoidAtAPublicPool,#ŞişliyiBatırdınİnönü,#25TemmuzDünyaKiloVermeGünü,#디스패치_도를넘어나대,Mbappé,#Ccs450,#Fan2IsOverParty,#KılıçdaroğluNeSöyledi,横浜優勝,#MyKoreanJagiyaTheReveal,#VenezuelaVotaEn5Dias,#TuesdayThoughts,#santiagoapostol,#NUESTW_If_You,#CFCFCB,#DiadaPatriaGalega,#仰天ニュース,天神祭,#cosasbuenas,#TercaDetremuraSDV,#SempreQuisTer,Artur Almeida,土用の丑の日,#Halilİnalcık,#マツコの知らない世界,#علي_سبيل_المزاج,#تركي_يعتدي_علي_سعوديين,#ابن_فهد_يجلد_ابن_زايد
# ('----------', 'us')
# Michael Kors,Taliban,#njmorningshow,#MIPmornings,23 STEM,#FreeRightsDefenders,Die Young,Attorney General Sessions,#iamup,Win A Copy Of The Book,Alice Cooper,House Intel,#BoyScoutSpeech,#TISL,O God,#25Jul,#FelizMartes,Barron Trump,#ThingsToAvoidAtAPublicPool,#markets,#MyIrrationalFearIn4Words,A.G.,Yano,#MyDreamTripWouldBe,The Daily 202,#SSZ1035,#Suffield,#RussiaSanctions,Mbappe,#TuesdayThoughts,#NamedMyShark,Luis Fonsi y Daddy Yankee,#LiveAtDaybreak,#GMRVA,#WhatILearnedToday,#CFCFCB,Ben Franklin Bridge,HAPPENING TODAY,#TravelTuesday,#PetFoodDrive,#nbc4ny,Justice Dept,#2bittues,#CAAFB,#13NewsNow,#AtlantaAlive,Gwinnett Co,What to Expect,Capitol Hill for 2nd,Comerica Park
# ('----------', 'san diego')
# Michael Kors,Taliban,#njmorningshow,#MIPmornings,23 STEM,#FreeRightsDefenders,Die Young,#iamup,Alice Cooper,House Intel,#BoyScoutSpeech,#JaredKushner,#TISL,#NationalTequilaDay,O God,#25Jul,#SharkWeek,#FelizMartes,Barron Trump,#Dodgers,#ThingsToAvoidAtAPublicPool,#markets,#MyIrrationalFearIn4Words,A.G.,Yano,#MyDreamTripWouldBe,The Daily 202,#SSZ1035,#Suffield,Mbappe,#TuesdayThoughts,#GameOfThrones,Luis Fonsi y Daddy Yankee,#LiveAtDaybreak,#WhatILearnedToday,#CFCFCB,Ben Franklin Bridge,HAPPENING TODAY,#TravelTuesday,#PetFoodDrive,Justice Dept,#2bittues,#CAAFB,Clayton Richard,#AtlantaAlive,Gwinnett Co,What to Expect,Kyrie Irving,Capitol Hill for 2nd,Comerica Park
# ('----------', 'philly')
# Michael Kors,Taliban,#njmorningshow,#MIPmornings,23 STEM,#FreeRightsDefenders,Die Young,#RHOC,Nick Williams,#iamup,Alice Cooper,House Intel,#BoyScoutSpeech,#BasketballWives,#TISL,#InsecureHBO,#NationalTequilaDay,O God,#25Jul,#FelizMartes,Barron Trump,#ThingsToAvoidAtAPublicPool,#markets,#MyIrrationalFearIn4Words,A.G.,Yano,#MyDreamTripWouldBe,#SSZ1035,#Suffield,Mbappe,#TuesdayThoughts,Luis Fonsi y Daddy Yankee,#TheBachelorette,#LiveAtDaybreak,#WhatILearnedToday,Ben Franklin Bridge,#LHHH,HAPPENING TODAY,#TravelTuesday,#PetFoodDrive,Justice Dept,#2bittues,#CAAFB,#Eagles,Gwinnett Co,#AtlantaAlive,What to Expect,Capitol Hill for 2nd,Comerica Park,Lawrence

# %%
# find trends that are happening in 2 different areas of the worrld
print(( '='*10,'Intersection of World and US Trends'))
print((trends_set['world'].intersection(trends_set['us'])),'\n')

print(('='*10,'Intersection of US and San Diego Trends'))
print((trends_set['san diego'].intersection(trends_set['us'])),'\n')

print(('='*10,'Intersection of Philadelphia and San Diego Trends'))
print((trends_set['san diego'].intersection(trends_set['philly'])))
# Out:
# ('==========', 'Intersection of World and US Trends')
# {'Michael Kors', '#25Jul', '#FelizMartes', '#TuesdayThoughts', '#CFCFCB', '#ThingsToAvoidAtAPublicPool'}
#
# ('==========', 'Intersection of US and San Diego Trends')
# {'Michael Kors', '#njmorningshow', 'Taliban', '#MIPmornings', '23 STEM', '#FreeRightsDefenders', 'Die Young', '#iamup', 'Alice Cooper', 'House Intel', '#BoyScoutSpeech', '#TISL', 'O God', '#25Jul', '#FelizMartes', 'Barron Trump', '#ThingsToAvoidAtAPublicPool', '#markets', '#MyIrrationalFearIn4Words', 'A.G.', 'Yano', '#MyDreamTripWouldBe', 'The Daily 202', '#SSZ1035', '#Suffield', 'Mbappe', '#TuesdayThoughts', 'Luis Fonsi y Daddy Yankee', '#LiveAtDaybreak', '#WhatILearnedToday', '#CFCFCB', 'Ben Franklin Bridge', 'HAPPENING TODAY', '#TravelTuesday', '#PetFoodDrive', 'Justice Dept', '#2bittues', '#CAAFB', '#AtlantaAlive', 'Gwinnett Co', 'What to Expect', 'Capitol Hill for 2nd', 'Comerica Park'}
#
# ('==========', 'Intersection of Philadelphia and San Diego Trends')
# {'Michael Kors', '#njmorningshow', 'Taliban', '#MIPmornings', '23 STEM', '#FreeRightsDefenders', 'Die Young', '#iamup', 'Alice Cooper', 'House Intel', '#BoyScoutSpeech', '#TISL', '#NationalTequilaDay', 'O God', '#25Jul', '#FelizMartes', 'Barron Trump', '#ThingsToAvoidAtAPublicPool', '#markets', '#MyIrrationalFearIn4Words', 'A.G.', 'Yano', '#MyDreamTripWouldBe', '#SSZ1035', '#Suffield', 'Mbappe', '#TuesdayThoughts', 'Luis Fonsi y Daddy Yankee', '#LiveAtDaybreak', '#WhatILearnedToday', 'Ben Franklin Bridge', 'HAPPENING TODAY', '#TravelTuesday', '#PetFoodDrive', 'Justice Dept', '#2bittues', '#CAAFB', '#AtlantaAlive', 'Gwinnett Co', 'What to Expect', 'Capitol Hill for 2nd', 'Comerica Park'}

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Set a variable `q` to a trending topic or anything else for that matter.
q = '#ThingsToAvoidAtAPublicPool' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

# search through all tweets for a specified number of tweets about a topic
search_results = twitter_api.search.tweets(q = q, count = number)

# get data from these tweets
statuses = search_results['statuses']

print(len(statuses),'\n')
print(statuses)
# Out:
# 100
#
# [{'created_at': 'Tue Jul 25 12:38:01 +0000 2017', 'id': 889827074546053120, 'id_str': '889827074546053120', 'text': 'RT @StopEatingBees: #ThingsToAvoidAtAPublicPool\n\nR. Kelly', 'truncated': False, 'entities': {'hashtags': [{'text': 'ThingsToAvoidAtAPublicPool', 'indices': [20, 47]}], 'symbols': [], 'user_mentions': [{'screen_name': 'StopEatingBees', 'name': 'Corey Miller', 'id': 633292225, 'id_str': '633292225', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 311797884, 'id_str': '311797884', 'name': 'Eddie Ferrero', 'screen_name': 'eddie_ferrero', 'location': 'Norman, OK', 'description': 'Abandoned by wolves. Raised by humans. Kind of an asshole. @midnight of the round table.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3255, 'friends_count': 3045, 'listed_count': 29, 'created_at': 'Mon Jun 06 02:35:33 +0000 2011', 'favourites_count': 11646, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 6844, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/806706716301664257/WERrTCM-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/806706716301664257/WERrTCM-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/311797884/1485757371', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Jul 25 11:01:11 +0000 2017', 'id': 889802707921498112, 'id_str': '889802707921498112', 'text': '#ThingsToAvoidAtAPublicPool\n\nR. Kelly', 'truncated': False, 'entities': {'hashtags': [{'text': 'ThingsToAvoidAtAPublicPool', 'indices': [0, 27]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 633292225, 'id_str': '633292225', 'name': 'Corey Miller', 'screen_name': 'StopEatingBees', 'location': 'Inside Amy Schumer', 'description': "I'm not perky. But I wanna be. One-time @midnight #PointsMe person of interest. Host of @MorallyBiased", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2356, 'friends_count': 730, 'listed_count': 41, 'created_at': 'Wed Jul 11 23:08:14 +0000 2012', 'favourites_count': 14738, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 20034, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_ti ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []

# for each actual tweet, if the tweet's text is not already in our list, add the tweet data is filtered_statuses
#   and the actual tweet text to all_text
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
        
statuses = filtered_statuses 
len(statuses)
# Out:
# 87

# %% [markdown]
# So we removed 13 duplicate statuses

# %%
# get the actual text/message for each tweet 
[s['text'] for s in statuses]
# Out:
# ['RT @StopEatingBees: #ThingsToAvoidAtAPublicPool\n\nR. Kelly',
#  '#ThingsToAvoidAtAPublicPool Getting your gear and building a private pool, only available for your closest family.',
#  'Drowning. #ThingsToAvoidAtAPublicPool',
#  'RT @TapleyMorgan: #CNNBlackmail posting on Reddit and getti mg blackmailed by CNN #ThingsToAvoidAtAPublicPool #CNNMemeWars',
#  'The Taliban\n#ThingsToAvoidAtAPublicPool',
#  "#ThingsToAvoidAtAPublicPool\n\n...the pool itself is a chlorinated stew of other people's bodily fluids.",
#  "That's why i love Hamburger 459\n#ThingsToAvoidّAtAPuَblicًPool\n#TuُeًsdaُyThouُghts\nMiًcِhael Korsُ\nhttps://t.co/l297FVUaU6",
#  '#ThingsToAvoidAtAPublicPool this https://t.co/rAjzXYAz7R',
#  'RT @geoffreyclark37: The public  #ThingsToAvoidAtAPublicPool',
#  'Getting in #ThingsToAvoidAtAPublicPool',
#  'The Pool itself !  #ThingsToAvoidAtAPublicPool',
#  '#ThingsToAvoidAtAPublicPool\n\nhttps://t.co/F4l6faFLmU',
#  '#ThingsToAvoidAtAPublicPool\n\nSomeone giving head in the pool',
#  'RT @SheaBrowning: This guy.\n\n--Diving boards, probably\n\n #ThingsToAvoidAtAPublicPool https://t.co/LzwTukvIWf',
#  'RT @Truthseer1961: #ThingsToAvoidAtAPublicPool \nRapefugees.',
#  '#ThingsToAvoidAtAPublicPool\nThe pool itself if you see Bill Cosby putting something in the water.',
#  "#ThingsToAvoidAtAPublicPool treat it's a pool not your",
#  'RT @Scottdell11: #ThingsToAvoidAtAPublicPool usher #scottdell',
#  'RT @robertrobq: #ThingsToAvoidAtAPublicPool Sharks,predators come in all shapes &amp; sizes,like Podesta for example.',
#  'Guys who say, "Ya know, I put the \'poo\' in \'pool.\'" And then wink. #ThingsToAvoidAtAPublicPool',
#  'The guy in the Speado  #ThingsToAvoidAtAPublicPool',
#  'RT @Cry_C: #ThingsToAvoidAtAPublicPool warm spots in the water.',
#  'RT @beaucoupbougee: THE POOL &amp; THE PUBLIC #ThingsToAvoidAtAPublicPool',
#  '#ThingsToAvoidAtAPublicPool\n\nhttps://t.co/til1G1OLUz',
#  '#ThingsToAvoidAtAPublicPool \n\nHizashi Yamada',
#  '#ThingsToAvoidAtAPublicPool\n\nEating and jumping in before 30 minutes',
#  'other people #ThingsToAvoidAtAPublicPool',
#  'RT @Sargon_of_Akkad: #ThingsToAvoidAtAPublicPool https://t.co/LG4cJzEsrn',
#  '#ThingsToAvoidAtAPublicPool Floaters https://t.co/gL6jYnWsjW',
#  '#ThingsToAvoidAtAPublicPool https://t.co/tvqMRAvQCc just to tweak some liberal commies this morning👌',
#  'RT @mmmPretZles: #ThingsToAvoidAtAPublicPool Black Jesus..    No..\nWait. \nWho am I kidding? That guy is awesome! https://t.co/AI8jCQ9cLO',
#  'Hungry Yoshis #ThingsToAvoidAtAPublicPool #RetroGaming #GamersUnite https://t.co/f9rP1uA6bO',
#  "Pretty much everything, based on the public pools I've been to recently. #ThingsToAvoidAtAPublicPool",
#  '#ThingsToAvoidAtAPublicPool ha, no one will think of this - floating candy bars! Ha!',
#  'RT @LiAisbackagain: #ThingsToAvoidAtAPublicPool\n@kurteichenwald doing "research" on young, nubile little boys for his CP "investigation for…',
#  'Small humans #ThingsToAvoidAtAPublicPool',
#  '#ThingsToAvoidAtAPublicPool  People who do not understand the difference between fast, medium and slow. Get in the fucking slow lane idiot!',
#  '#ThingsToAvoidAtAPublicPool - the entire pool.  Yuck!!',
#  '#ThingsToAvoidAtAPublicPool usher #scottdell',
#  '#ThingsToAvoidAtAPublicPool\n\n#immigrants',
#  'The pool #ThingsToAvoidAtAPublicPool',
#  '#ThingsToAvoidAtAPublicPool\nCommunity Swimming https://t.co/KobDnMEpHm',
#  'RT @ShutUpAmanda: #ThingsToAvoidAtAPublicPool\n\nPublic pools.',
#  "RT @10grandgiveaway: #ThingsToAvoidAtAPublicPool the kid shoveling sand into his little brother's diaper.  ...he's mean.",
#  'Men claiming to be from Syria #ThingsToAvoidAtAPublicPool',
#  '#ThingsToAvoidAtAPublicPool https://t.co/qzVSzZQ2Gt https://t.co/iphHEIM2oe',
#  '#ThingsToAvoidAtAPublicPool smoking should be avoived',
#  '#ThingsToAvoidAtAPublicPool pop up lemonade and chocolate pudding kiosks',
#  '#ThingsToAvoidAtAPublicPool - the wave pool https://t.co/30Nk6ZujZk',
#  'People  #ThingsToAvoidAtAPublicPool',
#  'RT @Tundextra: #ThingsToAvoidAtAPublicPool... Pool sharks https://t.co/kyCH5uZEHh',
#  '#ThingsToAvoidAtAPublicPool\n\n"Kids..."',
#  '#ThingsToAvoidAtAPublicPool \n\nLoose strings on your shorts. https://t.co/ipkYKjQmeE',
#  '#ThingsToAvoidAtAPublicPool …the pool.',
#  'My interns with Dunkin Donuts...oh at the pool? I thought you meant office?!? #ThingsToAvoidAtAPublicPool',
#  '#TuesdayThoughts #TuesdaySelfie #AddFamilyRuinASong #GetWoke #selfietuesday #ThingsToAvoidAtAPublicPool The Sun 🔥 https://t.co/Y2nZSbkow9',
#  'Skinny diping #ThingsToAvoidAtAPublicPool',
#  'The pool itself. #ThingsToAvoidAtAPublicPool',
#  'Eye contact. #ThingsToAvoidAtAPublicPool',
#  '#ThingsToAvoidAtAPublicPool: Going IN the pool...;-) #Ew #Tuesday #TuesdayMotivation #TuesdayThoughts',
#  '#ThingsToAvoidAtAPublicPool people that uses smartphones where it uncalled for',
#  'RT @nickiknowsnada: #ThingsToAvoidAtAPublicPool\nThe Snickers bar floating in the shallow end of the pool.',
#  'RT @CaseyKimberly: Italian Merchants #ThingsToAvoidAtAPublicPool https://t.co/s0XkAnLCMg',
#  '#ThingsToAvoidAtAPublicPool\nAmazing passing and water dunking https://t.co/YkhfeDyFCM',
#  '#ThingsToAvoidAtAPublicPool 🚼\n👇\n@realDonaldTrump 😨 https://t.co/KiGBe6ACWh',
#  '#ThingsToAvoidAtAPublicPool everything',
#  "RT @sman9876: That's why i love Hamburger 534\n#TuesdِaًyThoّughts\n#ThinّgsToَAvoَidّAtAPublicPoَoَl\nMicّhaeُl Korُs\nhttps://t.co/2sJSy9ma1q",
#  'Gingers #ThingsToAvoidAtAPublicPool',
#  '#ThingsToAvoidAtAPublicPool  Verucas',
#  'RT @omarkemkem: Is this a watermelon ? 236\n#ThingsToAvَoidَAtَAPublicPool\nMiٌchaٌeّl Kors\n#TuًeَsdaٍyThouًghts\nhttps://t.co/H2nhFaUqzU',
#  'RT @Angrypeanut4: #ThingsToAvoidAtAPublicPool \n\nthat one creepy guy 😖 https://t.co/oAcgn3WBjF',
#  '#CNNBlackmail posting on Reddit and getti mg blackmailed by CNN #ThingsToAvoidAtAPublicPool #CNNMemeWars',
#  '#ThingsToAvoidAtAPublicPool\nStay out of the water 💦',
#  '#ThingsToAvoidAtAPublicPool People 😂',
#  'RT @scrowder: The whales from Buzzfeed. #ThingsToAvoidAtAPublicPool',
#  'The poop!! #ThingsToAvoidAtAPublicPool',
#  '#ThingsToAvoidAtAPublicPool\nThat creepy old guy in the bananahammock.',
#  '#ThingsToAvoidAtAPublicPool  Pubic hair',
#  'RT @Cattereia: Looking too suspicious in the changerooms. #ThingsToAvoidAtAPublicPool https://t.co/ZC8iYutgPN',
#  'RT @_summerxx: @TWSnyderman The pool #ThingsToAvoidAtAPublicPool',
#  "The wine. It's atrocious. #ThingsToAvoidAtAPublicPool https://t.co/6AkixgGCfY",
#  '#ThingsToAvoidAtAPublicPool \n\nthe water',
#  '#ThingsToAvoidAtAPublicPool\n\nWearing a Thong https://t.co/nHIuMQWnje',
#  'RT @christen023: #ThingsToAvoidAtAPublicPool People with scabs',
#  '#ThingsToAvoidAtAPublicPool yellow water',
#  '@TWSnyderman The pool #ThingsToAvoidAtAPublicPool',
#  '#ThingsToAvoidAtAPublicPool   Brown floaters']

# %%
# Show 1 sample JSON search result by slicing the list
print(json.dumps(statuses[34], indent=1))
# Out:
# {
#  "created_at": "Tue Jul 25 12:36:40 +0000 2017",
#  "id": 889826733511372802,
#  "id_str": "889826733511372802",
#  "text": "RT @LiAisbackagain: #ThingsToAvoidAtAPublicPool\n@kurteichenwald doing \"research\" on young, nubile little boys for his CP \"investigation for\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "ThingsToAvoidAtAPublicPool",
#     "indices": [
#      20,
#      47
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "LiAisbackagain",
#     "name": "LiA is Back Again",
#     "id": 888386027135668224,
#     "id_str": "888386027135668224",
#     "indices": [
#      3,
#      18
#     ]
#    },
#    {
#     "screen_name": "kurteichenwald",
#     "name": "Kurt Eichenwald",
#     "id": 215207998,
#     "id_str": "215207998",
#     "indices": [
#      48,
#      63
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 2391320695,
#   "id_str": "2391320695",
#   "name": "The Deplorable Truth",
#   "screen_name": "LeftyLieBuster",
#   "location": "Nunyabidness",
#   "description": "#Bluehand Calling out the LIARS of Progressivism. List Adders get BLOCKED. Assholes get Muted (at the very least). #Gab.ai",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 1201,
#   "friends_count": 1154,
#   "listed_count": 18,
#   "created_at": "Sat Mar 15 16:42:13 +0000 2014",
#   "favourites_count": 17756,
#   "utc_offset": -25200,
#   "time_zone": "Pacific Time (US & Canada)",
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 19023,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/882639424399392768/Sj66H3cx_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/882639424399392768/Sj66H3cx_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2391320695/1456271664",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Tue Jul 25 12:18:44 +0000 2017",
#   "id": 889822220524150785,
#   "id_str": "889822220524150785",
#   "text": "#ThingsToAvoidAtAPublicPool\n@kurteichenwald doing \"research\" on young, nubile little boys for his CP \"investigation for the feds\".",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "ThingsToAvoidAtAPublicPool",
#      "indices": [
#       0,
#       27
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "kurteichenwald",
#      "name": "Kurt Eichenwald",
#      "id": 215207998,
#      "id_str": "215207998",
#      "indices": [
#       28,
#       43
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 888386027135668224,
#    "id_str": "888386027135668224",
#    "name": "LiA is Back Again",
#    "screen_name": "LiAisbackagain",
#    "location": "Novo",
#    "description": "Apparently @lauraloomer can't handle the bantz...who knew?",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 196,
#    "friends_count": 277,
#    "listed_count": 4,
#    "created_at": "Fri Jul 21 13:11:49 +0000 2017",
#    "favourites_count": 87,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 233,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/888388426944434177/rLxI8i2T_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/888388426944434177/rLxI8i2T_normal.jpg",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 5,
#   "favorite_count": 6,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 5,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only 1 element that can be accessed by its index 
# Set this list to the variable t
t = statuses[34]

#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'],'\n')
print(t['favorite_count'],'\n')
print(t['entities'],'\n')
print(t['user'],'\n')
print(t['lang'])
# Out:
# 5
#
# 0
#
# {'hashtags': [{'text': 'ThingsToAvoidAtAPublicPool', 'indices': [20, 47]}], 'symbols': [], 'user_mentions': [{'screen_name': 'LiAisbackagain', 'name': 'LiA is Back Again', 'id': 888386027135668224, 'id_str': '888386027135668224', 'indices': [3, 18]}, {'screen_name': 'kurteichenwald', 'name': 'Kurt Eichenwald', 'id': 215207998, 'id_str': '215207998', 'indices': [48, 63]}], 'urls': []}
#
# {'id': 2391320695, 'id_str': '2391320695', 'name': 'The Deplorable Truth', 'screen_name': 'LeftyLieBuster', 'location': 'Nunyabidness', 'description': '#Bluehand Calling out the LIARS of Progressivism. List Adders get BLOCKED. Assholes get Muted (at the very least). #Gab.ai', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1201, 'friends_count': 1154, 'listed_count': 18, 'created_at': 'Sat Mar 15 16:42:13 +0000 2014', 'favourites_count': 17756, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': False, 'statuses_count': 19023, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/882639424399392768/Sj66H3cx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/882639424399392768/Sj66H3cx_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2391320695/1456271664', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}
#
# en

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
#get the actual tweet message for each tweet
status_texts = [status['text'] for status in statuses]

# get the usernames from each tweet
screen_names = [user_mention['screen_name'] 
                 for status in statuses  # for each tweet retrieved
                     for user_mention in status['entities']['user_mentions'] ]  # for each user_mention in the "entity" dict

# get the usernames from each tweet
hashtags = [hashtag['text'] 
             for status in statuses # for each tweet retrieved 
                 for hashtag in status['entities']['hashtags']] # for each hashtag value in the "entity" dict

# Compute a collection of all words from all tweets
words = [w 
          for t in status_texts 
              for w in t.split()]

# %%
# Explore the first 5 items for each...
print(json.dumps(status_texts[0:5], indent = 1))
print(json.dumps(screen_names[0:5], indent = 1)) 
print(json.dumps(hashtags[0:5], indent = 1))
print(json.dumps(words[0:5], indent = 1))
# Out:
# [
#  "RT @StopEatingBees: #ThingsToAvoidAtAPublicPool\n\nR. Kelly",
#  "#ThingsToAvoidAtAPublicPool Getting your gear and building a private pool, only available for your closest family.",
#  "Drowning. #ThingsToAvoidAtAPublicPool",
#  "RT @TapleyMorgan: #CNNBlackmail posting on Reddit and getti mg blackmailed by CNN #ThingsToAvoidAtAPublicPool #CNNMemeWars",
#  "The Taliban\n#ThingsToAvoidAtAPublicPool"
# ]
# [
#  "StopEatingBees",
#  "TapleyMorgan",
#  "geoffreyclark37",
#  "SheaBrowning",
#  "Truthseer1961"
# ]
# [
#  "ThingsToAvoidAtAPublicPool",
#  "ThingsToAvoidAtAPublicPool",
#  "ThingsToAvoidAtAPublicPool",
#  "CNNBlackmail",
#  "ThingsToAvoidAtAPublicPool"
# ]
# [
#  "RT",
#  "@StopEatingBees:",
#  "#ThingsToAvoidAtAPublicPool",
#  "R.",
#  "Kelly"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets
#
# **Collections** package countains the **Counter** class which is very helpful.
#
# It helps us get lists of tuples for counts of items, and the **most_common()** method returns sorted counts

# %%
from collections import Counter

# for each list created above, count the top 10 of each (top 10 words used, screen names present, hashtags used)
for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('#ThingsToAvoidAtAPublicPool', 82), ('RT', 24), ('the', 19), ('The', 14), ('in', 12), ('pool', 9), ('and', 7), ('a', 5), ('on', 5), ('your', 4)]
#
# [('TWSnyderman', 2), ('StopEatingBees', 1), ('TapleyMorgan', 1), ('geoffreyclark37', 1), ('SheaBrowning', 1), ('Truthseer1961', 1), ('Scottdell11', 1), ('robertrobq', 1), ('Cry_C', 1), ('beaucoupbougee', 1)]
#
# [('ThingsToAvoidAtAPublicPool', 84), ('CNNBlackmail', 2), ('CNNMemeWars', 2), ('scottdell', 2), ('TuesdayThoughts', 2), ('ThingsToAvoidّAtAPuَblicًPool', 1), ('TuُeًsdaُyThouُghts', 1), ('RetroGaming', 1), ('GamersUnite', 1), ('immigrants', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format
#
# * Using **advanced string formatting**
#  * **{:20}** adds blank spaces to the end of the string for padding for 20 total spaces
#  * **{:^20}** centers a string within 20 spaces
#  * **{:>20}** adds blank spaces to the start of the string for padding (right-align) for 20 total spaces

# %%
def prettyprint_counts(label, list_of_tuples):
    # center the label w/in 20 spaces, add "|", right align the string 'Count' in 6 spaces
    # print line of *'s to seperate header from data
    # pring the key left-aligned with 20 overall spaces, print the value right-aligned w/ 6 total spaces
    
    print("\n{:^30} | {:^6}".format(label, "Count"))    
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:30} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data) # count up totals of each item in each of the 3 lists above
    prettyprint_counts(label, c.most_common()[:10]) # print out top 10 most common items in format from function
# Out:
#              Word              | Count
# ****************************************
# #ThingsToAvoidAtAPublicPool    |     82
# RT                             |     24
# the                            |     19
# The                            |     14
# in                             |     12
# pool                           |      9
# and                            |      7
# a                              |      5
# on                             |      5
# your                           |      4
#
#          Screen Name           | Count
# ****************************************
# TWSnyderman                    |      2
# StopEatingBees                 |      1
# TapleyMorgan                   |      1
# geoffreyclark37                |      1
# SheaBrowning                   |      1
# Truthseer1961                  |      1
# Scottdell11                    |      1
# robertrobq                     |      1
# Cry_C                          |      1
# beaucoupbougee                 |      1
#
#            Hashtag             | Count
# ****************************************
# ThingsToAvoidAtAPublicPool     |     84
# CNNBlackmail                   |      2
# CNNMemeWars                    |      2
# scottdell                      |      2
# TuesdayThoughts                |      2
# ThingsToAvoidّAtAPuَblicًPool  |      1
# TuُeًsdaُyThouُghts            |      1
# RetroGaming                    |      1
# GamersUnite                    |      1
# immigrants                     |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store a tuple of 3 values:
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}" # right align, center, left align
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the 1st 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse = True)[:5])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#   67    | geoffreyclark37 | RT @geoffreyclark37: The public  #ThingsToAvoidAtA
#         |                 | PublicPool
#   49    | StopEatingBees  | RT @StopEatingBees: #ThingsToAvoidAtAPublicPool\\R
#         |                 | . Kelly
#   27    |      Cry_C      | RT @Cry_C: #ThingsToAvoidAtAPublicPool warm spots
#         |                 | in the water.
#   27    |    Cattereia    | RT @Cattereia: Looking too suspicious in the chang
#         |                 | erooms. #ThingsToAvoidAtAPublicPool https://t.co/Z
#         |                 | C8iYutgPN
#   23    |    sman9876     | RT @sman9876: That's why i love Hamburger 534\#Tue
#         |                 | sdِaًyThoّughts\#ThinّgsToَAvoَidّAtAPublicPoَoَl\
#         |                 | Micّhaeُl Korُs\https://t.co/2sJSy9ma1q
