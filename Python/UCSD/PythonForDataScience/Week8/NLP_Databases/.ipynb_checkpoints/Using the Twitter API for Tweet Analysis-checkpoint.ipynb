# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements **OAuth 1.0A** as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# **pkl** is a Python utility module that does **serialization** to convert any Python object or data structure to a character stream so that it can be saved to the disk and recreated in Python if we need it later.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.17.1-py2.py3-none-any.whl (55kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.17.1

# %%
if not os.path.exists('C:/ml/twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('C:/ml/twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('C:/ml/twitter_credentials.pkl','rb'))

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

## use twitter keys from pkl file to create twitter api object in python

# create authentication object
auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

# create twitter api object
twitter_api = twitter.Twitter(auth = auth)

# Nothing to see by displaying twitter_api except that it's now a defined variable
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000000005243C50>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the **Yahoo! Where On Earth ID**.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
SANDIEGO_LOCAL_WOE_ID = 2487889
PHILLY_LOCAL_WOE_ID = 2471217

# Prefix ID argument in .trends.place() with the underscore for query string parameterization.
#     - Without underscore, twitter package appends the ID value to the URL itself as a special case keyword argument.

# get top 50 trends from various areas via a trend object in JSON
world_trends = twitter_api.trends.place(_id = WORLD_WOE_ID) # = 1
us_trends = twitter_api.trends.place(_id = US_WOE_ID) # = 23424977
sd_trends = twitter_api.trends.place(_id = SANDIEGO_LOCAL_WOE_ID) # = 2487889
philly_trends = twitter_api.trends.place(_id = PHILLY_LOCAL_WOE_ID) # = 2487889


# see top 2 world trends
world_trends[:2]
# Out:
# [{'as_of': '2017-07-24T14:39:39Z',
#   'created_at': '2017-07-24T14:36:55Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': 'Paint',
#     'promoted_content': None,
#     'query': 'Paint',
#     'tweet_volume': 85712,
#     'url': 'http://twitter.com/search?q=Paint'},
#    {'name': '#FelizLunes',
#     'promoted_content': None,
#     'query': '%23FelizLunes',
#     'tweet_volume': 32243,
#     'url': 'http://twitter.com/search?q=%23FelizLunes'},
#    {'name': '#MondayMotivation',
#     'promoted_content': None,
#     'query': '%23MondayMotivation',
#     'tweet_volume': 97920,
#     'url': 'http://twitter.com/search?q=%23MondayMotivation'},
#    {'name': '#LahoreBlast',
#     'promoted_content': None,
#     'query': '%23LahoreBlast',
#     'tweet_volume': 19575,
#     'url': 'http://twitter.com/search?q=%23LahoreBlast'},
#    {'name': '#24Jul',
#     'promoted_content': None,
#     'query': '%2324Jul',
#     'tweet_volume': 32089,
#     'url': 'http://twitter.com/search?q=%2324Jul'},
#    {'name': '#توطين_البقالات',
#     'promoted_content': None,
#     'query': '%23%D8%AA%D9%88%D8%B7%D9%8A%D9%86_%D8%A7%D9%84%D8%A8%D9%82%D8%A7%D9%84%D8%A7%D8%AA',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%AA%D9%88%D8%B7%D9%8A%D9%86_%D8%A7%D9%84%D8%A8%D9%82%D8%A7%D9%84%D8%A7%D8%AA'},
#    {'name': 'Jared Kushner',
#     'promoted_content': None,
#     'query': '%22Jared+Kushner%22',
#     'tweet_volume': 88129,
#     'url': 'http://twitter.com/search?q=%22Jared+Kushner%22'},
#    {'name': 'Yoko Ono',
#     'promoted_content': None,
#     'query': '%22Yoko+Ono%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Yoko+Ono%22'},
#    {'name': 'Benjamin Mendy',
#     'promoted_content': None,
#     'query': '%22Benjamin+Mendy%22',
#     'tweet_volume': 31184,
#     'url': 'http://twitter.com/search?q=%22Benjamin+Mendy%22'},
#    {'name': '真剣佑',
#     'promoted_content': None,
#     'query': '%E7%9C%9F%E5%89%A3%E4%BD%91',
#     'tweet_volume': 22479,
#     'url': 'http://twitter.com/search?q=%E7%9C%9F%E5%89%A3%E4%BD%91'},
#    {'name': "Eto'o",
#     'promoted_content': None,
#     'query': 'Eto%27o',
#     'tweet_volume': 16725,
#     'url': 'http://twitter.com/search?q=Eto%27o'},
#    {'name': 'Bekir Bozdağ',
#     'promoted_content': None,
#     'query': '%22Bekir+Bozda%C4%9F%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Bekir+Bozda%C4%9F%22'},
#    {'name': 'VIVEGAM TEASER 500K LIKES',
#     'promoted_content': None,
#     'query': '%22VIVEGAM+TEASER+500K+LIKES%22',
#     'tweet_volume': 10544,
#     'url': 'http://twitter.com/search?q=%22VIVEGAM+TEASER+500K+LIKES%22'},
#    {'name': 'Benzema Beşiktaşta',
#     'promoted_content': None,
#     'query': '%22Benzema+Be%C5%9Fikta%C5%9Fta%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Benzema+Be%C5%9Fikta%C5%9Fta%22'},
#    {'name': '#NationalTequilaDay',
#     'promoted_content': None,
#     'query': '%23NationalTequilaDay',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NationalTequilaDay'},
#    {'name': '#LaLunaSangreHinala',
#     'promoted_content': None,
#     'query': '%23LaLunaSangreHinala',
#     'tweet_volume': 106480,
#     'url': 'http://twitter.com/search?q=%23LaLunaSangreHinala'},
#    {'name': '#SONA2017',
#     'promoted_content': None,
#     'query': '%23SONA2017',
#     'tweet_volume': 96303,
#     'url': 'http://twitter.com/search?q=%23SONA2017'},
#    {'name': '#CosasInsoportables',
#     'promoted_content': None,
#     'query': '%23CosasInsoportables',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23CosasInsoportables'},
#    {'name': '#YoureAtABadHotelIf',
#     'promoted_content': None,
#     'query': '%23YoureAtABadHotelIf',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23YoureAtABadHotelIf'},
#    {'name': '#اسعد_شعور_اذا',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D8%B3%D8%B9%D8%AF_%D8%B4%D8%B9%D9%88%D8%B1_%D8%A7%D8%B0%D8%A7',
#     'tweet_volume': 73560,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D8%B3%D8%B9%D8%AF_%D8%B4%D8%B9%D9%88%D8%B1_%D8%A7%D8%B0%D8%A7'},
#    {'name': '#SuperChef',
#     'promoted_content': None,
#     'query': '%23SuperChef',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SuperChef'},
#    {'name': '#BTSisComing',
#     'promoted_content': None,
#     'query': '%23BTSisComing',
#     'tweet_volume': 124444,
#     'url': 'http://twitter.com/search?q=%23BTSisComing'},
#    {'name': '#SegundaDetremuraSdv',
#     'promoted_content': None,
#     'query': '%23SegundaDetremuraSdv',
#     'tweet_volume': 13212,
#     'url': 'http://twitter.com/search?q=%23SegundaDetremuraSdv'},
#    {'name': '#PDG36',
#     'promoted_content': None,
#     'query': '%23PDG36',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PDG36'},
#    {'name': '#Lozan',
#     'promoted_content': None,
#     'query': '%23Lozan',
#     'tweet_volume': 29036,
#     'url': 'http://twitter.com/search?q=%23Lozan'},
#    {'name': '#qanda',
#     'promoted_content': None,
#     'query': '%23qanda',
#     'tweet_volume': 12079,
#     'url': 'http://twitter.com/search?q=%23qanda'},
#    {'name': '#TrocoFalsianesPor',
#     'promoted_content': None,
#     'query': '%23TrocoFalsianesPor',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TrocoFalsianesPor'},
#    {'name': '#コードブルー',
#     'promoted_content': None,
#     'query': '%23%E3%82%B3%E3%83%BC%E3%83%89%E3%83%96%E3%83%AB%E3%83%BC',
#     'tweet_volume': 23626,
#     'url': 'http://twitter.com/search?q=%23%E3%82%B3%E3%83%BC%E3%83%89%E3%83%96%E3%83%AB%E3%83%BC'},
#    {'name': '#あなたっぽいにゃんこ',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%A3%E3%81%BD%E3%81%84%E3%81%AB%E3%82%83%E3%82%93%E3%81%93',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%A3%E3%81%BD%E3%81%84%E3%81%AB%E3%82%83%E3%82%93%E3%81%93'},
#    {'name': '#GazetecilereÖzgürlük',
#     'promoted_content': None,
#     'query': '%23Gazetecilere%C3%96zg%C3%BCrl%C3%BCk',
#     'tweet_volume': 28532,
#     'url': 'http://twitter.com/search?q=%23Gazetecilere%C3%96zg%C3%BCrl%C3%BCk'},
#    {'name': '#EnLunesSiempreYo',
#     'promoted_content': None,
#     'query': '%23EnLunesSiempreYo',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23EnLunesSiempreYo'},
#    {'name': '#Schaffhausen',
#     'promoted_content': None,
#     'query': '%23Schaffhausen',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Schaffhausen'},
#    {'name': '#انا_مسلمه_اتميز_بحجابي',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%86%D8%A7_%D9%85%D8%B3%D9%84%D9%85%D9%87_%D8%A7%D8%AA%D9%85%D9%8A%D8%B2_%D8%A8%D8%AD%D8%AC%D8%A7%D8%A8%D9%8A',
#     'tweet_volume': 28032,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%86%D8%A7_%D9%85%D8%B3%D9%84%D9%85%D9%87_%D8%A7%D8%AA%D9%85%D9%8A%D8%B2_%D8%A8%D8%AD%D8%AC%D8%A7%D8%A8%D9%8A'},
#    {'name': '#ALTLTrashTalk',
#     'promoted_content': None,
#     'query': '%23ALTLTrashTalk',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ALTLTrashTalk'},
#    {'name': '#InterOL',
#     'promoted_content': None,
#     'query': '%23InterOL',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23InterOL'},
#    {'name': '#Cassano',
#     'promoted_content': None,
#     'query': '%23Cassano',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Cassano'},
#    {'name': '#30LuYaşlarda',
#     'promoted_content': None,
#     'query': '%2330LuYa%C5%9Flarda',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%2330LuYa%C5%9Flarda'},
#    {'name': '#cambiame513',
#     'promoted_content': None,
#     'query': '%23cambiame513',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23cambiame513'},
#    {'name': '#مجلس_الوزراء',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%AC%D9%84%D8%B3_%D8%A7%D9%84%D9%88%D8%B2%D8%B1%D8%A7%D8%A1',
#     'tweet_volume': 22722,
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%AC%D9%84%D8%B3_%D8%A7%D9%84%D9%88%D8%B2%D8%B1%D8%A7%D8%A1'},
#    {'name': '#ElRidiculoMasGrandeEs',
#     'promoted_content': None,
#     'query': '%23ElRidiculoMasGrandeEs',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ElRidiculoMasGrandeEs'},
#    {'name': '#BasınBayramı',
#     'promoted_content': None,
#     'query': '%23Bas%C4%B1nBayram%C4%B1',
#     'tweet_volume': 10770,
#     'url': 'http://twitter.com/search?q=%23Bas%C4%B1nBayram%C4%B1'},
#    {'name': '#AndIWouldDoItAgain',
#     'promoted_content': None,
#     'query': '%23AndIWouldDoItAgain',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AndIWouldDoItAgain'},
#    {'name': '#muchogusto',
#     'promoted_content': None,
#     'query': '%23muchogusto',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23muchogusto'},
#    {'name': '#BoschKullanma',
#     'promoted_content': None,
#     'query': '%23BoschKullanma',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23BoschKullanma'},
#    {'name': '#BlueMendy',
#     'promoted_content': None,
#     'query': '%23BlueMendy',
#     'tweet_volume': 10973,
#     'url': 'http://twitter.com/search?q=%23BlueMendy'},
#    {'name': '#HoraDoVeneno',
#     'promoted_content': None,
#     'query': '%23HoraDoVeneno',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HoraDoVeneno'},
#    {'name': '#SantosCompraTrinos',
#     'promoted_content': None,
#     'query': '%23SantosCompraTrinos',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SantosCompraTrinos'},
#    {'name': '#PorLaMañana',
#     'promoted_content': None,
#     'query': '%23PorLaMa%C3%B1ana',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PorLaMa%C3%B1ana'},
#    {'name': '#PurposeTourMovie',
#     'promoted_content': None,
#     'query': '%23PurposeTourMovie',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PurposeTourMovie'},
#    {'name': '#DidemMadak',
#     'promoted_content': None,
#     'query': '%23DidemMadak',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23DidemMadak'}]}]

# %% [markdown]
# API responses are in **JSON (JavaScript Object Notation)** format, which is used to transfer data on the web and is roughly equivalent to nested Python lists and dictionaries, or 'more-concise' XML
#
# Top 2 trends as of 7/24/2017, 9:59 AM EST are "#FelizLunes" and "#MondayMotivation"

# %%
# see type of the trends object
print(type(sd_trends),'\n')

# see the keys from the 1st record/object
print(list(sd_trends[0].keys()),'\n')

# see the trend data from the 1st object
print(sd_trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
#
# ['trends', 'as_of', 'created_at', 'locations']
#
# [{'name': '#InsecureHBO', 'url': 'http://twitter.com/search?q=%23InsecureHBO', 'promoted_content': None, 'query': '%23InsecureHBO', 'tweet_volume': 127537}, {'name': '#ElTriEng', 'url': 'http://twitter.com/search?q=%23ElTriEng', 'promoted_content': None, 'query': '%23ElTriEng', 'tweet_volume': None}, {'name': '#WWEBattleground', 'url': 'http://twitter.com/search?q=%23WWEBattleground', 'promoted_content': None, 'query': '%23WWEBattleground', 'tweet_volume': 227952}, {'name': '#NW88JR', 'url': 'http://twitter.com/search?q=%23NW88JR', 'promoted_content': None, 'query': '%23NW88JR', 'tweet_volume': None}, {'name': '#SDCC2017', 'url': 'http://twitter.com/search?q=%23SDCC2017', 'promoted_content': None, 'query': '%23SDCC2017', 'tweet_volume': 102633}, {'name': 'Jared Kushner', 'url': 'http://twitter.com/search?q=%22Jared+Kushner%22', 'promoted_content': None, 'query': '%22Jared+Kushner%22', 'tweet_volume': 88129}, {'name': 'Paint', 'url': 'http://twitter.com/search?q=Paint', 'promoted_content': None, 'query': 'Paint', 'tweet_volume': 85712}, {'name': "Bush's Baked Beans", 'url': 'http://twitter.com/search?q=%22Bush%27s+Baked+Beans%22', 'promoted_content': None, 'query': '%22Bush%27s+Baked+Beans%22', 'tweet_volume': None}, {'name': 'Ray Tensing', 'url': 'http://twitter.com/search?q=%22Ray+Tensing%22', 'promoted_content': None, 'query': '%22Ray+Tensing%22', 'tweet_volume': None}, {'name': 'Rudy Giuliani', 'url': 'http://twitter.com/search?q=%22Rudy+Giuliani%22', 'promoted_content': None, 'query': '%22Rudy+Giuliani%22', 'tweet_volume': None}, {'name': 'Dan Rooney', 'url': 'http://twitter.com/search?q=%22Dan+Rooney%22', 'promoted_content': None, 'query': '%22Dan+Rooney%22', 'tweet_volume': None}, {'name': 'Kent Island', 'url': 'http://twitter.com/search?q=%22Kent+Island%22', 'promoted_content': None, 'query': '%22Kent+Island%22', 'tweet_volume': None}, {'name': 'WR Anquan Boldin', 'url': 'http://twitter.com/search?q=%22WR+Anquan+Boldin%22', 'promoted_content': None, 'query': '%22WR+Anquan+Boldin%22', 'tweet_volume': None}, {'name': 'Foster', 'url': 'http://twitter.com/search?q=Foster', 'promoted_content': None, 'query': 'Foster', 'tweet_volume': 32354}, {'name': 'The Kook', 'url': 'http://twitter.com/search?q=%22The+Kook%22', 'promoted_content': None, 'query': '%22The+Kook%22', 'tweet_volume': None}, {'name': 'Sidney Jones', 'url': 'http://twitter.com/search?q=%22Sidney+Jones%22', 'promoted_content': None, 'query': '%22Sidney+Jones%22', 'tweet_volume': None}, {'name': 'Greg Ward', 'url': 'http://twitter.com/search?q=%22Greg+Ward%22', 'promoted_content': None, 'query': '%22Greg+Ward%22', 'tweet_volume': None}, {'name': 'Interstate Bridge', 'url': 'http://twitter.com/search?q=%22Interstate+Bridge%22', 'promoted_content': None, 'query': '%22Interstate+Bridge%22', 'tweet_volume': None}, {'name': 'Suga Free', 'url': 'http://twitter.com/search?q=%22Suga+Free%22', 'promoted_content': None, 'query': '%22Suga+Free%22', 'tweet_volume': None}, {'name': 'GenX', 'url': 'http://twitter.com/search?q=GenX', 'promoted_content': None, 'query': 'GenX', 'tweet_volume': None}, {'name': 'Alexandre Dumas', 'url': 'http://twitter.com/search?q=%22Alexandre+Dumas%22', 'promoted_content': None, 'query': '%22Alexandre+Dumas%22', 'tweet_volume': None}, {'name': 'Chuck Schumer', 'url': 'http://twitter.com/search?q=%22Chuck+Schumer%22', 'promoted_content': None, 'query': '%22Chuck+Schumer%22', 'tweet_volume': 38447}, {'name': 'Sherrod Brown', 'url': 'http://twitter.com/search?q=%22Sherrod+Brown%22', 'promoted_content': None, 'query': '%22Sherrod+Brown%22', 'tweet_volume': None}, {'name': 'Morning Joe', 'url': 'http://twitter.com/search?q=%22Morning+Joe%22', 'promoted_content': None, 'query': '%22Morning+Joe%22', 'tweet_volume': None}, {'name': 'Santana Row', 'url': 'http://twitter.com/search?q=%22Santana+Row%22', 'promoted_content': None, 'query': '%22Santana+Row%22', 'tweet_volume': None}, {'name': 'Mack Hollins', 'url': 'http://twitter.com/search?q=%22Mack+Hollins% ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

# get a more-formatted version of JSON output with indents for every new level
print((json.dumps(us_trends[:2], indent = 1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#MondayMotivation",
#     "url": "http://twitter.com/search?q=%23MondayMotivation",
#     "promoted_content": null,
#     "query": "%23MondayMotivation",
#     "tweet_volume": 87024
#    },
#    {
#     "name": "Jared Kushner",
#     "url": "http://twitter.com/search?q=%22Jared+Kushner%22",
#     "promoted_content": null,
#     "query": "%22Jared+Kushner%22",
#     "tweet_volume": 77242
#    },
#    {
#     "name": "#YoureAtABadHotelIf",
#     "url": "http://twitter.com/search?q=%23YoureAtABadHotelIf",
#     "promoted_content": null,
#     "query": "%23YoureAtABadHotelIf",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NationalTequilaDay",
#     "url": "http://twitter.com/search?q=%23NationalTequilaDay",
#     "promoted_content": null,
#     "query": "%23NationalTequilaDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FelizLunes",
#     "url": "http://twitter.com/search?q=%23FelizLunes",
#     "promoted_content": null,
#     "query": "%23FelizLunes",
#     "tweet_volume": 26785
#    },
#    {
#     "name": "#100RCSummit",
#     "url": "http://twitter.com/search?q=%23100RCSummit",
#     "promoted_content": null,
#     "query": "%23100RCSummit",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sleazy Adam Schiff",
#     "url": "http://twitter.com/search?q=%22Sleazy+Adam+Schiff%22",
#     "promoted_content": null,
#     "query": "%22Sleazy+Adam+Schiff%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kent Island",
#     "url": "http://twitter.com/search?q=%22Kent+Island%22",
#     "promoted_content": null,
#     "query": "%22Kent+Island%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bush's Baked Beans",
#     "url": "http://twitter.com/search?q=%22Bush%27s+Baked+Beans%22",
#     "promoted_content": null,
#     "query": "%22Bush%27s+Baked+Beans%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lahore",
#     "url": "http://twitter.com/search?q=Lahore",
#     "promoted_content": null,
#     "query": "Lahore",
#     "tweet_volume": 23919
#    },
#    {
#     "name": "Ray Tensing",
#     "url": "http://twitter.com/search?q=%22Ray+Tensing%22",
#     "promoted_content": null,
#     "query": "%22Ray+Tensing%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Foster",
#     "url": "http://twitter.com/search?q=Foster",
#     "promoted_content": null,
#     "query": "Foster",
#     "tweet_volume": 32347
#    },
#    {
#     "name": "Sidney Jones",
#     "url": "http://twitter.com/search?q=%22Sidney+Jones%22",
#     "promoted_content": null,
#     "query": "%22Sidney+Jones%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dan Rooney",
#     "url": "http://twitter.com/search?q=%22Dan+Rooney%22",
#     "promoted_content": null,
#     "query": "%22Dan+Rooney%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "I-5 SB",
#     "url": "http://twitter.com/search?q=%22I-5+SB%22",
#     "promoted_content": null,
#     "query": "%22I-5+SB%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Paint",
#     "url": "http://twitter.com/search?q=Paint",
#     "promoted_content": null,
#     "query": "Paint",
#     "tweet_volume": 70370
#    },
#    {
#     "name": "Drain the Sewer",
#     "url": "http://twitter.com/search?q=%22Drain+the+Sewer%22",
#     "promoted_content": null,
#     "query": "%22Drain+the+Sewer%22",
#     "tweet_volume": 18632
#    },
#    {
#     "name": "Sherrod Brown",
#     "url": "http://twitter.com/search?q=%22Sherrod+Brown%22",
#     "promoted_content": null,
#     "query": "%22Sherrod+Brown%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Suga Free",
#     "url": "http://twitter.com/search?q=%22Suga+Free%22",
#     "promoted_content": null,
#     "query": "%22Suga+Free%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "'Despacito'",
#     "url": "http://twitter.com/search?q=%27Despacito%27",
#     "promoted_content": null,
#     "query": "%27Despacito%27",
#     "tweet_volume": 81081
#    },
#    {
#     "name": "Santana Row",
#     "url": "http://twitter.com/search?q=%22Santana+Row%22",
#     "promoted_content": null,
#     "query": "%22Santana+Row%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chuck Schumer",
#     "url": "http://twitter.com/search?q=%22Chuck+Schumer%22",
#     "promoted_content": null,
#     "query": "%22Chuck+Schumer%22",
#     "tweet_volume": 35646
#    },
#    {
#     "name": "Morning Joe",
#     "url": "http://twitter.com/search?q=%22Morning+Joe%22",
#     "promoted_content": null,
#     "query": "%22Morning+Joe%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Stevensville",
#     "url": "http://twitter.com/search?q=Stevensville",
#     "promoted_content": null,
#     "query": "Stevensville",
#     "tweet_volume": null
#    },
#    {
#     "name": "Suiza",
#     "url": "http://twitter.com/search?q=Suiza",
#     "promoted_content": null,
#     "query": "Suiza",
#     "tweet_volume": null
#    },
#    {
#     "name": "Alexandre Dumas",
#     "url": "http://twitter.com/search?q=%22Alexandre+Dumas%22",
#     "promoted_content": null,
#     "query": "%22Alexandre+Dumas%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "WebMD",
#     "url": "http://twitter.com/search?q=WebMD",
#     "promoted_content": null,
#     "query": "WebMD",
#     "tweet_volume": null
#    },
#    {
#     "name": "Adrian Peterson",
#     "url": "http://twitter.com/search?q=%22Adrian+Peterson%22",
#     "promoted_content": null,
#     "query": "%22Adrian+Peterson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Heimlich",
#     "url": "http://twitter.com/search?q=Heimlich",
#     "promoted_content": null,
#     "query": "Heimlich",
#     "tweet_volume": null
#    },
#    {
#     "name": "My Gay Agenda",
#     "url": "http://twitter.com/search?q=%22My+Gay+Agenda%22",
#     "promoted_content": null,
#     "query": "%22My+Gay+Agenda%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Liam Fox",
#     "url": "http://twitter.com/search?q=%22Liam+Fox%22",
#     "promoted_content": null,
#     "query": "%22Liam+Fox%22",
#     "tweet_volume": 13368
#    },
#    {
#     "name": "HoloLens",
#     "url": "http://twitter.com/search?q=HoloLens",
#     "promoted_content": null,
#     "query": "HoloLens",
#     "tweet_volume": null
#    },
#    {
#     "name": "Stono River",
#     "url": "http://twitter.com/search?q=%22Stono+River%22",
#     "promoted_content": null,
#     "query": "%22Stono+River%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "5 in Swiss",
#     "url": "http://twitter.com/search?q=%225+in+Swiss%22",
#     "promoted_content": null,
#     "query": "%225+in+Swiss%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Inner Loop",
#     "url": "http://twitter.com/search?q=%22Inner+Loop%22",
#     "promoted_content": null,
#     "query": "%22Inner+Loop%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "USS Constitution",
#     "url": "http://twitter.com/search?q=%22USS+Constitution%22",
#     "promoted_content": null,
#     "query": "%22USS+Constitution%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ShootYourShot",
#     "url": "http://twitter.com/search?q=%23ShootYourShot",
#     "promoted_content": null,
#     "query": "%23ShootYourShot",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PioneerDay",
#     "url": "http://twitter.com/search?q=%23PioneerDay",
#     "promoted_content": null,
#     "query": "%23PioneerDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#VBAmazing",
#     "url": "http://twitter.com/search?q=%23VBAmazing",
#     "promoted_content": null,
#     "query": "%23VBAmazing",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ABetterDeal",
#     "url": "http://twitter.com/search?q=%23ABetterDeal",
#     "promoted_content": null,
#     "query": "%23ABetterDeal",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MuseMon",
#     "url": "http://twitter.com/search?q=%23MuseMon",
#     "promoted_content": null,
#     "query": "%23MuseMon",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ThingsIAlwaysSeemToForget",
#     "url": "http://twitter.com/search?q=%23ThingsIAlwaysSeemToForget",
#     "promoted_content": null,
#     "query": "%23ThingsIAlwaysSeemToForget",
#     "tweet_volume": null
#    },
#    {
#     "name": "#redline",
#     "url": "http://twitter.com/search?q=%23redline",
#     "promoted_content": null,
#     "query": "%23redline",
#     "tweet_volume": null
#    },
#    {
#     "name": "#e3Tech",
#     "url": "http://twitter.com/search?q=%23e3Tech",
#     "promoted_content": null,
#     "query": "%23e3Tech",
#     "tweet_volume": null
#    },
#    {
#     "name": "#5HOnFallon",
#     "url": "http://twitter.com/search?q=%235HOnFallon",
#     "promoted_content": null,
#     "query": "%235HOnFallon",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SHMS",
#     "url": "http://twitter.com/search?q=%23SHMS",
#     "promoted_content": null,
#     "query": "%23SHMS",
#     "tweet_volume": null
#    },
#    {
#     "name": "#c4ignite",
#     "url": "http://twitter.com/search?q=%23c4ignite",
#     "promoted_content": null,
#     "query": "%23c4ignite",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NatlCancerForum",
#     "url": "http://twitter.com/search?q=%23NatlCancerForum",
#     "promoted_content": null,
#     "query": "%23NatlCancerForum",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SSZ1035",
#     "url": "http://twitter.com/search?q=%23SSZ1035",
#     "promoted_content": null,
#     "query": "%23SSZ1035",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OPEC",
#     "url": "http://twitter.com/search?q=%23OPEC",
#     "promoted_content": null,
#     "query": "%23OPEC",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2017-07-24T13:59:13Z",
#   "created_at": "2017-07-24T13:51:50Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two *sets* of trends
#
# i.e. Find commonalities in the trends from different locations

# %%
# create empty set
trends_set = {}

# from the list value of the 'trends' key from the dictionary in the JSON response, go through each dictionary element w/in
#   the list and get the value from the 'name' key and keep only unique ones
trends_set['world'] = set(trend['name'] for trend in world_trends[0]['trends'])

trends_set['us'] = set(trend['name'] for trend in us_trends[0]['trends'])

trends_set['san diego'] = set(trend['name'] for trend in sd_trends[0]['trends'])

trends_set['philly'] = set(trend['name'] for trend in philly_trends[0]['trends'])

# %%
# join the datasets together and loop through them to get each trend from each set 
for loc in ['world','us','san diego','philly']:
    print(('-'*10,loc))
# Out:
# ('----------', 'world')
# Benzema Beşiktaşta,#LahoreBlast,#コードブルー,#MondayMotivation,#YoureAtABadHotelIf,#Schaffhausen,#SantosCompraTrinos,#SegundaDetremuraSdv,#SONA2017,#DidemMadak,#ElRidiculoMasGrandeEs,#LaLunaSangreHinala,真剣佑,#qanda,#BlueMendy,#PDG36,#muchogusto,#cambiame513,#HoraDoVeneno,#InterOL,#EnLunesSiempreYo,#PorLaMañana,Paint,#TrocoFalsianesPor,#30LuYaşlarda,#PurposeTourMovie,#توطين_البقالات,#Cassano,#BasınBayramı,Jared Kushner,#ALTLTrashTalk,Eto'o,#انا_مسلمه_اتميز_بحجابي,#مجلس_الوزراء,#BoschKullanma,#BTSisComing,#SuperChef,#NationalTequilaDay,#AndIWouldDoItAgain,#あなたっぽいにゃんこ,Bekir Bozdağ,#اسعد_شعور_اذا,#FelizLunes,Benjamin Mendy,#Lozan,#CosasInsoportables,#GazetecilereÖzgürlük,VIVEGAM TEASER 500K LIKES,Yoko Ono,#24Jul
#
# ('----------', 'us')
# Dan Rooney,NEW SHOW,#MondayMotivation,#YoureAtABadHotelIf,#ShootYourShot,Ray Tensing,#SchoologyNEXT,#FunBelt,Interstate Bridge,#B1GMediaDay,#TrainingCamp,Bush's Baked Beans,Alexandre Dumas,Kent Island,Sherrod Brown,Greg Ward,Foster,Santana Row,#MuseMon,Rudy Giuliani,Kabul,Mack Hollins,#beinternetawesome,#VBAmazing,#c4ignite,Paint,Donnel Pumphrey,SF-86,#SHMS,#100RCsummit,#ThingsIAlwaysSeemToForget,Morning Joe,Jerrell Freeman,Jared Kushner,Sidney Jones,#ABetterDeal,#NationalTequilaDay,#AndIWouldDoItAgain,#5HonFallon,Suga Free,Chuck Schumer,GenX,#FelizLunes,Drain the Sewer,Suiza,WR Anquan Boldin,The Kook,#24Jul,#PioneerDay,#AreYouPrepared
#
# ('----------', 'san diego')
# Dan Rooney,NEW SHOW,#MondayMotivation,#YoureAtABadHotelIf,#ShootYourShot,Ray Tensing,#SchoologyNEXT,#FunBelt,Interstate Bridge,#B1GMediaDay,Bush's Baked Beans,Alexandre Dumas,Kent Island,Sherrod Brown,Greg Ward,Foster,Santana Row,#MuseMon,Rudy Giuliani,#InsecureHBO,Kabul,Mack Hollins,#beinternetawesome,#VBAmazing,#c4ignite,Paint,#WWEBattleground,#100RCsummit,#ThingsIAlwaysSeemToForget,Morning Joe,#ElTriEng,Jared Kushner,Sidney Jones,#ABetterDeal,#NationalTequilaDay,#AndIWouldDoItAgain,#SDCC2017,#GameOfThrones,#5HonFallon,Suga Free,Chuck Schumer,#NW88JR,GenX,Drain the Sewer,#observing,#FelizLunes,WR Anquan Boldin,The Kook,#24Jul,#PioneerDay
#
# ('----------', 'philly')
# Dan Rooney,Sleazy Adam Schiff,#MondayMotivation,#YoureAtABadHotelIf,#ShootYourShot,Ray Tensing,#EaglesCamp,#SchoologyNEXT,#FunBelt,Interstate Bridge,WebMD,#B1GMediaDay,Bush's Baked Beans,Alexandre Dumas,Kent Island,Sherrod Brown,Foster,Santana Row,#MuseMon,Rudy Giuliani,Senate Intel Committee,#InsecureHBO,Kabul,#beinternetawesome,#VBAmazing,#c4ignite,Paint,#WWEBattleground,#ThronesYall,Donnel Pumphrey,#SHMS,#ThingsIAlwaysSeemToForget,Jerrell Freeman,Jared Kushner,#ABetterDeal,#SharkWeek,#NationalTequilaDay,#AndIWouldDoItAgain,Who Can't,#5HonFallon,Suga Free,Chuck Schumer,GenX,#FelizLunes,Drain the Sewer,Suiza,#24Jul,Adrian Peterson,#PioneerDay,#AreYouPrepared

# %%
# find trends that are happening in 2 different areas of the worrld
print(( '='*10,'Intersection of World and US Trends'))
print((trends_set['world'].intersection(trends_set['us'])),'\n')

print(('='*10,'Intersection of US and San Diego Trends'))
print((trends_set['san diego'].intersection(trends_set['us'])),'\n')

print(('='*10,'Intersection of Philadelphia and San Diego Trends'))
print((trends_set['san diego'].intersection(trends_set['philly'])))
# Out:
# ('==========', 'Intersection of World and US Trends')
# {'#MondayMotivation', '#YoureAtABadHotelIf', 'Jared Kushner', '#FelizLunes', '#NationalTequilaDay', '#24Jul', 'Paint', '#AndIWouldDoItAgain'}
#
# ('==========', 'Intersection of US and San Diego Trends')
# {'Dan Rooney', 'NEW SHOW', '#MondayMotivation', '#YoureAtABadHotelIf', '#ShootYourShot', 'Ray Tensing', '#SchoologyNEXT', '#FunBelt', 'Interstate Bridge', '#B1GMediaDay', "Bush's Baked Beans", 'Kent Island', 'Alexandre Dumas', 'Sherrod Brown', 'Greg Ward', 'Foster', 'Santana Row', '#MuseMon', 'Rudy Giuliani', 'Kabul', 'Mack Hollins', '#beinternetawesome', '#VBAmazing', '#c4ignite', 'Paint', '#100RCsummit', '#ThingsIAlwaysSeemToForget', 'Morning Joe', 'Jared Kushner', 'Sidney Jones', '#ABetterDeal', '#NationalTequilaDay', '#AndIWouldDoItAgain', '#5HonFallon', 'Suga Free', 'Chuck Schumer', 'GenX', '#FelizLunes', 'Drain the Sewer', 'WR Anquan Boldin', 'The Kook', '#24Jul', '#PioneerDay'}
#
# ('==========', 'Intersection of Philadelphia and San Diego Trends')
# {'Dan Rooney', '#MondayMotivation', '#YoureAtABadHotelIf', '#ShootYourShot', 'Ray Tensing', '#SchoologyNEXT', '#FunBelt', 'Interstate Bridge', '#B1GMediaDay', "Bush's Baked Beans", 'Kent Island', 'Alexandre Dumas', 'Sherrod Brown', 'Foster', 'Santana Row', '#MuseMon', 'Rudy Giuliani', '#InsecureHBO', 'Kabul', '#beinternetawesome', '#VBAmazing', '#c4ignite', 'Paint', '#WWEBattleground', '#ThingsIAlwaysSeemToForget', 'Jared Kushner', '#ABetterDeal', '#NationalTequilaDay', '#AndIWouldDoItAgain', '#5HonFallon', 'Suga Free', 'Chuck Schumer', 'GenX', '#FelizLunes', 'Drain the Sewer', '#24Jul', '#PioneerDay'}

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Set a variable `q` to a trending topic or anything else for that matter.
q = '#YoureAtABadHotelIf' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

# search through all tweets for a specified number of tweets about a topic
search_results = twitter_api.search.tweets(q = q, count = number)

# get data from these tweets
statuses = search_results['statuses']

print(len(statuses),'\n')
print(statuses)
# Out:
# 100
#
# [{'created_at': 'Mon Jul 24 15:19:50 +0000 2017', 'id': 889505411052732416, 'id_str': '889505411052732416', 'text': '#YoureAtABadHotelIf theres urine stains on the carpet', 'truncated': False, 'entities': {'hashtags': [{'text': 'YoureAtABadHotelIf', 'indices': [0, 19]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 923987281, 'id_str': '923987281', 'name': 'carl brown', 'screen_name': 'carlbrown1978', 'location': '', 'description': 'theres not much in life worth worrying about, so enjoy,  middlesbrough', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1001, 'friends_count': 1133, 'listed_count': 3, 'created_at': 'Sat Nov 03 20:30:15 +0000 2012', 'favourites_count': 109, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3648, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000855894034/08aba3ed7ef0ffa85df65184caa13842_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000855894034/08aba3ed7ef0ffa85df65184caa13842_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/923987281/1382293786', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, {'created_at': 'Mon Jul 24 15:19:47 +0000 2017', 'id': 889505395743576066, 'id_str': '889505395743576066', 'text': 'RT @SheaBrowning: #YoureAtABadHotelIf the roach at the check in counter escorts you to your room.', 'truncated': False, 'entities': {'hashtags': [{'text': 'YoureAtABadHotelIf', 'indices': [18, 37]}], 'symbols': [], 'user_mentions': [{'screen_name': 'SheaBrowning', 'name': 'Shea Browning', 'id': 25776495, 'id_str': '25776495', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 808722445440024577, 'id_str': '808722445440024577', 'name': 'Kaegan Laveau', 'screen_name': 'Kaegan_xo', 'location': 'Bless your ❤, SC', 'description': '❤Angela Bassett ❤Michelle Obama ❤Paula Abdul ❤JK Rowling #LiBERAL #americanHORRORstory #NEWorleans #nursingSTUDENT #GIFqueen #books', 'url': 'https://t.co/gNP6jj9mgc', 'entities': {'url': {'urls': [{'url': 'https://t.co/gNP6jj9mgc', 'expanded_url': 'http://misskaeganxo.tumblr.com', 'display_url': 'misskaeganxo.tumblr.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 54, 'friends_count': 285, 'listed_count': 1, 'created_at': 'Tue Dec 13 17:17:11 +0000 2016', 'favourites_count': 590, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, ' ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []

# for each actual tweet, if the tweet's text is not already in our list, add the tweet data is filtered_statuses
#   and the actual tweet text to all_text
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
        
statuses = filtered_statuses 
len(statuses)
# Out:
# 94

# %% [markdown]
# So we removed 6 duplicate statuses

# %%
# get the actual text/message for each tweet 
[s['text'] for s in statuses]
# Out:
# ['#YoureAtABadHotelIf theres urine stains on the carpet',
#  'RT @SheaBrowning: #YoureAtABadHotelIf the roach at the check in counter escorts you to your room.',
#  '#YoureAtABadHotelIf you stay in Staten Island.',
#  '#YoureAtABadHotelIf instead of HBO, your room just has BO.',
#  '#YoureAtABadHotelIf the hotel manager can determine the cause and time of death more accurately than the police coroner.',
#  "#YoureAtABadHotelIf You don't have those little candies on the desk in the lobby.",
#  'RT @helenmaryme: #YoureAtABadHotelIf you call down for an extra towel, and they tell you that you have to wait because someone else is usin…',
#  "RT @geoffreyclark37: #YoureAtABadHotelIf when you check in, the guy at the counter asks if you're really sure you want to stay here.",
#  "#YoureAtABadHotelIf you turn on the TV 📺 and the only channel's that you get are porn. 🍆💦 https://t.co/QTkWcvFLoF",
#  '#YoureAtABadHotelIf https://t.co/k0WG2GLgrK',
#  'Charge your phone 5x faster\nhttps://t.co/muqBLXzM4c\n#MondayMotivation #NationalTequilaDay #YoureAtABadHotelIf #MusicMonday #ParentSchmovies',
#  "RT @BookstrOfficial: #YoureAtABadHotelIf you don't provide a library! https://t.co/nXbcjbVhCK",
#  '#YoureAtABadHotelIf you wake up covered in itchy bug bites....',
#  "#YoureAtABadHotelIf there's a chainsaw in the lobby",
#  "#YoureAtABadHotelIf\n\nI won't stay there.",
#  '#YoureAtABadHotelIf\nthe shower head doubles as the ice machine',
#  'RT @googlygirl98: #YoureAtABadHotelIf the pamphlet lists the gas station across the street as a "local attraction" and 7-11 as a (4-star) "…',
#  '#YoureAtABadHotelIf the bed moves and you arent in it',
#  '#YoureAtABadHotelIf the guy who checks you in say "We all go a little mad sometimes." https://t.co/r9pVKhcv4q',
#  '#YoureAtABadHotelIf half the letters on the neon marquee are burned out. https://t.co/96CMnoneN6',
#  "#YoureAtABadHotelIf it's in Cleveland or Detroit or Mosul.",
#  'RT @LockesAlterEgo: The owners are a man and his dead mother #YoureAtABadHotelIf',
#  'It smells like sex and Candy! #YoureAtABadHotelIf',
#  "#MuseMon: #YoureAtABadHotelIf you're a #Trump and you can't checkout of this new soon to be the #Trump family towers https://t.co/AW7gMij501",
#  'RT @LouBrutus: #YoureAtABadHotelIf You call to the Captain to please bring you your wine but he informs you, "We haven\'t had that spirit he…',
#  "#YoureAtABadHotelIf you'd prefer to shower while still wearing your socks and/or shoes. Yikes! :) https://t.co/Hl6DqLwQcR",
#  "#YoureAtABadHotelIf the staff is unable to personally recommend fine dining &amp; upscale entertainment because they're unable to afford it 🌎🍌🌟",
#  '#YoureAtABadHotelIf hair floats up out of the drain while you are showering. #truestory',
#  '#youreatabadhotelif the shag carpet is sticky on your feet',
#  "RT @Alohababe2011: #YoureAtABadHotelIf you're able to check in but you can't check out",
#  '#YoureAtABadHotelIf if the manager refuses to harm that fly buzzing around him https://t.co/ApBRPyqYqD',
#  '#YoureAtABadHotelIf \rWhen you pull up they are taking someone out on a stretcher',
#  '#YoureAtABadHotelIf you ask me if I want the hourly or nightly rate at check-in.',
#  'RT @ErinRHazel: #YoureAtABadHotelIf \nGoogle Maps changes your name to Dump Tower. DRAIN THE SEWER\n#MondayMotivaton\n#JaredKushner #ABetterDe…',
#  "#YoureAtABadHotelIf the mop water's red",
#  "#YoureAtABadHotelIf it doesn't look anything like the pictures on the website.",
#  '#YoureAtABadHotelIf You meet a hooker on the way to your room',
#  '#YoureAtABadHotelIf the guy getting arrested in the parking lot crashes thru your window with cuffs on trying to run from the cops. 💥',
#  "#YoureAtABadHotelIf you don't need a UV light to see all of the stains.",
#  'RT @JMoney731: #YoureAtABadHotelIf the bedbugs have their own keys',
#  '#YoureAtABadHotelIf the water is black and tastes funny. 😬 https://t.co/v5MqC4ExKc',
#  '#YoureAtABadHotelIf bugs are everywhere 😬',
#  "RT @AaliyahNevaeh7: #YoureAtABadHotelIf they don't allow dogs 🐶😉 https://t.co/OUKva7uM0G",
#  '#YoureAtABadHotelIf your sheets are made out of paper.',
#  '#YoureAtABadHotelIf when their is a door that divides two rooms',
#  'Your room key is attached to a toilet seat. \n\n#YoureAtABadHotelIf',
#  '#YoureAtABadHotelIf there is a giant cooler full of water bottles available because you should not use the running water (true story).',
#  '#YoureAtABadHotelIf there are mystery stains on the bed sheets.',
#  'The air vents are made from bullet holes.  #YoureAtABadHotelIf',
#  '#YoureAtABadHotelIf your room door is off the hinges',
#  '#YoureAtABadHotelIf they ask you which shift you prefer for your turn on night watch.',
#  "RT @Del_Piero_Mamba: #YoureAtABadHotelIf you're forced to watch fake news like 🤢CNN and 🤢MSNBC; and there's no Fox News on any channel.",
#  '#YoureAtABadHotelIf you roll over open your eyes and Chris Christie has his swimsuit on',
#  '#YoureAtABadHotelIf you have to clean your own sheets.',
#  'You see twins  #YoureAtABadHotelIf https://t.co/MDiZbb2MkJ',
#  '#YoureAtABadHotelIf the WiFi they are referring to in their sign stands for Wicked Fireants',
#  '#YoureAtABadHotelIf You check in at 3 a.m. and the place is super busy with people checking in and out.... 😀',
#  '#YoureAtABadHotelIf pro wrestlers wrecks it more rock stars',
#  '#YoureAtABadHotelIf the wake-up calls are done in person. https://t.co/82l0HCnukk',
#  '#YoureAtABadHotelIf\nthe bed bugs have lined up to spell: "SAVE YOURSELF WHILE YOU CAN"',
#  "RT @AgathaChocolats: #YoureAtABadHotelIf there's no chocolate on the pillow...I'm still looking for a good hotel.😔 https://t.co/v2OZLTTxVA",
#  '#YoureAtABadHotelIf anything in your room is labeled "Coin-Op."',
#  'RT @Dan081275: #YoureAtABadHotelIf There is a peep hole cut in the wall so you can see the guests next door',
#  '#YoureAtABadHotelIf it only has 1-ply toilet paper.....and the toilet paper rack is ten feet away from the toilet!',
#  '#YoureAtABadHotelIf the roaches line up on the wall to spell out the word SCHMUCK to insult you for staying there.',
#  '#YoureAtABadHotelIf\n\nThese guys are visiting;\n(*´･o･)\n\nhttps://t.co/Tp8GCxJZxQ',
#  'If the shower is too narrow for your shoulders. #truestory #YoureAtABadHotelIf',
#  '#YoureAtABadHotelIf the door numbers are written in blood.',
#  'RT @LukeWheeler01: #YoureAtABadHotelIf it says Bates on the front of it',
#  "#YoureAtABadHotelIf if they don't have #Foxnews but they have #Fakenews #Cnn @chucktodd @Acosta @ChrisCuomo… https://t.co/ZK9b5mnhI4",
#  '#YoureAtABadHotelIf You can check out any time you like,\nBut you can never leave!',
#  '#YoureAtABadHotelIf the bed has a coin operated vibrator next to it.',
#  '#YoureAtABadHotelIf they have to keep putting febreeze on the carpet every half hour lol - a hotel in Montreal.',
#  "RT @ThatsMissThot2U: Fox Host Picks Fun at Democrat For 'Better Deal' Slogan #MondayMotivation  #YoureAtABadHotelIf your talking about 'Pod…",
#  "RT @MelodyUnplugged: You start itching all over. Ditch your luggage or you'll bring that shit back home with you! #YoureAtABadHotelIf",
#  "#YoureAtABadHotelIf you're forced to watch fake news like 🤢CNN and 🤢MSNBC; and there's no Fox News on any channel.",
#  '#YoureAtABadHotelIf the sheets are moving before you get in them 🐜',
#  '#YoureAtABadHotelIf the clerk looks like #AnthonyPerkins #Psycho',
#  "You feel the urge to turn on a black light. Don't do it! #YoureAtABadHotelIf https://t.co/tjnErPaW0h",
#  '#YoureAtABadHotelIf there are pubes in your bed sheets...',
#  '#Danger #YoureAtABadHotelIf your child eaten by gator at @DisneyWorld https://t.co/ILqRbWrMuB via @YouTube https://t.co/DB7QBVWB4H',
#  'RT @HepatitisAtoZ: #YoureAtABadHotelIf you are woken in the middle of the night by several people screaming "who are you and why are you in…',
#  "#YoureAtABadHotelIf it's a 10-minute run from where the #Uber drops you off.",
#  '#YoureAtABadHotelIf they refold the used towels',
#  '#YoureAtABadHotelIf The rats and roaches give it 1 star....',
#  '#YoureAtABadHotelIf your room rate is based on 20-minute stays. https://t.co/snTfWk6Ga1',
#  '#YoureAtABadHotelIf the continental breakfast comes with raisin scones...and the raisins move.',
#  '#YoureAtABadHotelIf you get on the elevator, push your floor number, and the person next to you says, "4th floor huh?" then laughs.',
#  "#YoureAtABadHotelIf You don't book your Howard Homecoming Trip with us! #NYU2021 #NYU2020 #NYU2019 #NYU2018 #huhc #howardhomecoming",
#  '#YoureAtABadHotelIf it is called the Hotel California and you plan to both check out AND leave.',
#  'RT @wevegan: #YoureAtABadHotelIf\nthere are no #Vegan options.\n#MondayMotivation https://t.co/0MFx8fIhHe',
#  'The mirror on the bathroom wall is two-way. #YoureAtABadHotelIf',
#  'RT @ShomahKhoobi: #YoureAtABadHotelIf you see the "Trump" sign on the building',
#  'RT @jW5U3CpcD096eQZ: WT.\nhttps://t.co/8xFWcw7Vue\n\n#MondayMotivationِ\n#NationalTequilaDayِ\nJared Kushnerِ\n#YoureAtABadHotelIfِ\n#100RCsummitِ…']

# %%
# Show 1 sample JSON search result by slicing the list
print(json.dumps(statuses[1], indent=1))
# Out:
# {
#  "created_at": "Mon Jul 24 15:19:47 +0000 2017",
#  "id": 889505395743576066,
#  "id_str": "889505395743576066",
#  "text": "RT @SheaBrowning: #YoureAtABadHotelIf the roach at the check in counter escorts you to your room.",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "YoureAtABadHotelIf",
#     "indices": [
#      18,
#      37
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "SheaBrowning",
#     "name": "Shea Browning",
#     "id": 25776495,
#     "id_str": "25776495",
#     "indices": [
#      3,
#      16
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Lite</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 808722445440024577,
#   "id_str": "808722445440024577",
#   "name": "Kaegan Laveau",
#   "screen_name": "Kaegan_xo",
#   "location": "Bless your \u2764, SC",
#   "description": "\u2764Angela Bassett \u2764Michelle Obama \u2764Paula Abdul \u2764JK Rowling #LiBERAL #americanHORRORstory #NEWorleans #nursingSTUDENT #GIFqueen #books",
#   "url": "https://t.co/gNP6jj9mgc",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/gNP6jj9mgc",
#       "expanded_url": "http://misskaeganxo.tumblr.com",
#       "display_url": "misskaeganxo.tumblr.com",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 54,
#   "friends_count": 285,
#   "listed_count": 1,
#   "created_at": "Tue Dec 13 17:17:11 +0000 2016",
#   "favourites_count": 590,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 612,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "000000",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/884898378685050881/rHE6F9ZV_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/884898378685050881/rHE6F9ZV_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/808722445440024577/1498992174",
#   "profile_link_color": "1B95E0",
#   "profile_sidebar_border_color": "000000",
#   "profile_sidebar_fill_color": "000000",
#   "profile_text_color": "000000",
#   "profile_use_background_image": false,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Mon Jul 24 11:59:34 +0000 2017",
#   "id": 889455009859076098,
#   "id_str": "889455009859076098",
#   "text": "#YoureAtABadHotelIf the roach at the check in counter escorts you to your room.",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "YoureAtABadHotelIf",
#      "indices": [
#       0,
#       19
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 25776495,
#    "id_str": "25776495",
#    "name": "Shea Browning",
#    "screen_name": "SheaBrowning",
#    "location": "Georgia",
#    "description": "Husband-Dad-Lawyer-Hashtagger. Host of @EsquireTags on Thursdays @ 8amET w/@HashtagRoundup. 5x a @midnight bridesmaid not yet a @midnight bride. RT connoisseur.",
#    "url": "https://t.co/T2t65Gh9Xe",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/T2t65Gh9Xe",
#        "expanded_url": "https://twitter.com/search?q=from%3Asheabrowning%20-replies&src=typd",
#        "display_url": "twitter.com/search?q=from%\u2026",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 6163,
#    "friends_count": 2502,
#    "listed_count": 80,
#    "created_at": "Sun Mar 22 03:49:10 +0000 2009",
#    "favourites_count": 29819,
#    "utc_offset": -14400,
#    "time_zone": "Eastern Time (US & Canada)",
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 32253,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/521045018430029825/7emxdtdS.jpeg",
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/521045018430029825/7emxdtdS.jpeg",
#    "profile_background_tile": true,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/883387504568741888/0klM6uFE_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/883387504568741888/0klM6uFE_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/25776495/1499484855",
#    "profile_link_color": "558844",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "EFEFEF",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 43,
#   "favorite_count": 152,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 43,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only 1 element that can be accessed by its index 
# Set this list to the variable t
t = statuses[1]

#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'],'\n')
print(t['favorite_count'],'\n')
print(t['entities'],'\n')
print(t['user'],'\n')
print(t['lang'])
# Out:
# 43
#
# 0
#
# {'hashtags': [{'text': 'YoureAtABadHotelIf', 'indices': [18, 37]}], 'symbols': [], 'user_mentions': [{'screen_name': 'SheaBrowning', 'name': 'Shea Browning', 'id': 25776495, 'id_str': '25776495', 'indices': [3, 16]}], 'urls': []}
#
# {'id': 808722445440024577, 'id_str': '808722445440024577', 'name': 'Kaegan Laveau', 'screen_name': 'Kaegan_xo', 'location': 'Bless your ❤, SC', 'description': '❤Angela Bassett ❤Michelle Obama ❤Paula Abdul ❤JK Rowling #LiBERAL #americanHORRORstory #NEWorleans #nursingSTUDENT #GIFqueen #books', 'url': 'https://t.co/gNP6jj9mgc', 'entities': {'url': {'urls': [{'url': 'https://t.co/gNP6jj9mgc', 'expanded_url': 'http://misskaeganxo.tumblr.com', 'display_url': 'misskaeganxo.tumblr.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 54, 'friends_count': 285, 'listed_count': 1, 'created_at': 'Tue Dec 13 17:17:11 +0000 2016', 'favourites_count': 590, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 612, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/884898378685050881/rHE6F9ZV_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/884898378685050881/rHE6F9ZV_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/808722445440024577/1498992174', 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}
#
# en

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
#get the actual tweet message for each tweet
status_texts = [status['text'] for status in statuses ]

# get the usernames from each tweet
screen_names = [user_mention['screen_name'] 
                 for status in statuses  # for each tweet retrieved
                     for user_mention in status['entities']['user_mentions'] ]  # for each user_mention in the "entity" dict

# get the usernames from each tweet
hashtags = [hashtag['text'] 
             for status in statuses # for each tweet retrieved 
                 for hashtag in status['entities']['hashtags']] # for each hashtag value in the "entity" dict

# Compute a collection of all words from all tweets
words = [w 
          for t in status_texts 
              for w in t.split()]

# %%
# Explore the first 5 items for each...
print(json.dumps(status_texts[0:5], indent = 1))
print(json.dumps(screen_names[0:5], indent = 1)) 
print(json.dumps(hashtags[0:5], indent = 1))
print(json.dumps(words[0:5], indent = 1))
# Out:
# [
#  "#YoureAtABadHotelIf theres urine stains on the carpet",
#  "RT @SheaBrowning: #YoureAtABadHotelIf the roach at the check in counter escorts you to your room.",
#  "#YoureAtABadHotelIf you stay in Staten Island.",
#  "#YoureAtABadHotelIf instead of HBO, your room just has BO.",
#  "#YoureAtABadHotelIf the hotel manager can determine the cause and time of death more accurately than the police coroner."
# ]
# [
#  "SheaBrowning",
#  "helenmaryme",
#  "geoffreyclark37",
#  "BookstrOfficial",
#  "googlygirl98"
# ]
# [
#  "YoureAtABadHotelIf",
#  "YoureAtABadHotelIf",
#  "YoureAtABadHotelIf",
#  "YoureAtABadHotelIf",
#  "YoureAtABadHotelIf"
# ]
# [
#  "#YoureAtABadHotelIf",
#  "theres",
#  "urine",
#  "stains",
#  "on"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

# for each list created above, count the top 10 of each (top 10 words used, screen names present, hashtags used)
for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('#YoureAtABadHotelIf', 92), ('the', 74), ('you', 38), ('to', 28), ('on', 23), ('your', 23), ('RT', 21), ('in', 21), ('and', 20), ('are', 19)]
#
# [('SheaBrowning', 1), ('helenmaryme', 1), ('geoffreyclark37', 1), ('BookstrOfficial', 1), ('googlygirl98', 1), ('LockesAlterEgo', 1), ('LouBrutus', 1), ('Alohababe2011', 1), ('ErinRHazel', 1), ('JMoney731', 1)]
#
# [('YoureAtABadHotelIf', 92), ('MondayMotivation', 3), ('Trump', 2), ('truestory', 2), ('NationalTequilaDay', 1), ('MusicMonday', 1), ('ParentSchmovies', 1), ('MuseMon', 1), ('youreatabadhotelif', 1), ('MondayMotivaton', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
