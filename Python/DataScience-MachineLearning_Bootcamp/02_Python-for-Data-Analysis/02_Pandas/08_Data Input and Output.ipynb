# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('example')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports **data**. NOT formulas or images, so having images or macros may cause the read_excel() method to crash.

# %% [markdown]
# ### Excel Input

# %%
pd.read_excel('Excel_Sample.xlsx',sheetname='Sheet1')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
#returns a list because Pandas tries to find every table element in the HTMl file via <table> tags
#it finds each element, makes a list of them, and wants to convert each list into a Data Frame
# Out:
# [                                  Bank Name                City  ST   CERT  \
#  0                             Proficio Bank  Cottonwood Heights  UT  35495
#  1             Seaway Bank and Trust Company             Chicago  IL  19328
#  2                    Harvest Community Bank          Pennsville  NJ  34951
#  3                               Allied Bank            Mulberry  AR     91
#  4              The Woodbury Banking Company            Woodbury  GA  11297
#  5                    First CornerStone Bank     King of Prussia  PA  35312
#  6                        Trust Company Bank             Memphis  TN   9956
#  7                North Milwaukee State Bank           Milwaukee  WI  20364
#  8                    Hometown National Bank            Longview  WA  35156
#  9                       The Bank of Georgia      Peachtree City  GA  35259
#  10                             Premier Bank              Denver  CO  34112
# ...

# %%
#get the data frame that is the 1st item in the list
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
df[0]
# Out:
#                                   Bank Name                City  ST   CERT  \
# 0                             Proficio Bank  Cottonwood Heights  UT  35495
# 1             Seaway Bank and Trust Company             Chicago  IL  19328
# 2                    Harvest Community Bank          Pennsville  NJ  34951
# 3                               Allied Bank            Mulberry  AR     91
# 4              The Woodbury Banking Company            Woodbury  GA  11297
# 5                    First CornerStone Bank     King of Prussia  PA  35312
# 6                        Trust Company Bank             Memphis  TN   9956
# 7                North Milwaukee State Bank           Milwaukee  WI  20364
# 8                    Hometown National Bank            Longview  WA  35156
# 9                       The Bank of Georgia      Peachtree City  GA  35259
# 10                             Premier Bank              Denver  CO  34112
# ...

# %% [markdown]
# _____
# _____
# # SQL (Optional)
#
# * Note: If you are completely unfamiliar with SQL you can check out my other course: "Complete SQL Bootcamp" to learn SQL.

# %% [markdown]
# The **pandas.io.sql module** provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by **SQLAlchemy** if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
# If SQLAlchemy is not installed, a fallback is only provided for *sqlite* (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * **read_sql_table(table_name, con[, schema, ...])**
#     * Read SQL database table into a DataFrame.
# * **read_sql_query(sql, con[, index_col, ...])**
#     * Read SQL query into a DataFrame.
# * **read_sql(sql, con[, index_col, ...])**
#     * Read SQL query OR database table into a DataFrame.
# * **DataFrame.to_sql(name, con[, flavor, ...])	**
#     * Write records stored in a DataFrame to a SQL database.

# %%
from sqlalchemy import create_engine

# %%
#build a SQL engine in memory
engine = create_engine('sqlite:///:memory:')

# %%
#write our table from above to the SQL engine/database
df[0].to_sql('my_bank_tbl', engine)

# %%
#get the data frame back out of the SQL engine/database
#  con = engine --> connection = engine
sql_df = pd.read_sql('my_bank_tbl', con = engine)
sql_df
# Out:
#      index                               Bank Name                City  ST  \
# 0        0                           Proficio Bank  Cottonwood Heights  UT
# 1        1           Seaway Bank and Trust Company             Chicago  IL
# 2        2                  Harvest Community Bank          Pennsville  NJ
# 3        3                             Allied Bank            Mulberry  AR
# 4        4            The Woodbury Banking Company            Woodbury  GA
# 5        5                  First CornerStone Bank     King of Prussia  PA
# 6        6                      Trust Company Bank             Memphis  TN
# 7        7              North Milwaukee State Bank           Milwaukee  WI
# 8        8                  Hometown National Bank            Longview  WA
# 9        9                     The Bank of Georgia      Peachtree City  GA
# 10      10                            Premier Bank              Denver  CO
# ...

# %% [markdown]
# # Great Job!
