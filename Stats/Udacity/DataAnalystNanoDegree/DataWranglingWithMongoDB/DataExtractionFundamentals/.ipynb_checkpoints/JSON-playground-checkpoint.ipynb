# %%
import json
import requests

# %%
# get URL to web service that grants access to its music data 
BASE_URL = "http://musicbrainz.org/ws/2/"
# get artist metadata (type of data/entity)
ARTIST_URL = BASE_URL + "artist/"

# %%
# QUERY PARAMETERS are given to the requests.get() function as a dictionary
# This variable contains some starter parameters.
query_type = {  "simple": {},
                "atr": {"inc": "aliases+tags+ratings"},
                "aliases": {"inc": "aliases"},
                "releases": {"inc": "releases"}}

# %%
# need unique identifier of artist to get their data
def query_site(url, params, uid="", fmt="json"):
    """
    Main function for making queries to musicbrainz API - should return a JSON document.
    """
    params["fmt"] = fmt
	# returned request JSON object
    r = requests.get(url + uid, params = params)
	# message to user
    print( "requesting", r.url, '.....\n')
	
	# check that request went through
    if r.status_code == requests.codes.ok:
        return r.json()
    else:
        r.raise_for_status()

# %%
def query_by_name(url, params, name):
    """
    Adds given artist name to given url + query parameters before making API call to the JSON returned from query_site()
    """
    params["query"] = "artist:" + name
    return query_site(url, params)

# %%
def pretty_print(data, indent=4):
    """
    Format output to be more readable.
    """
    if type(data) == dict:
	# convert JSON object to string with .dumps()
        print( json.dumps(data, indent = indent, sort_keys = True))
    else:
        print( data)

# %%
# Query for info in the database about bands named Nirvana
results = query_by_name(ARTIST_URL, query_type["simple"], "Nirvana")
pretty_print(results)
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?fmt=json&query=artist%3ANirvana .....
#
# {
#     "artists": [
#         {
#             "area": {
#                 "id": "6a264f94-6ff1-30b1-9a81-41f7bfabd616",
#                 "name": "Finland",
#                 "sort-name": "Finland"
#             },
#             "country": "FI",
#             "disambiguation": "Early 1980's Finnish punk band",
#             "id": "85af0709-95db-4fbc-801a-120e9f4766d0",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "finland"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "disambiguation": "founded in 1987 by a Michael Jackson double/imitator",
#             "id": "3aa878c0-224b-41e5-abd1-63be359d2bca",
#             "life-span": {
#                 "begin": "1987",
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana"
#         },
#         {
#             "disambiguation": "French band from Martigues, activ during the 70s.",
#             "id": "c49d69dc-e008-47cf-b5ff-160fafb1fe1f",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "name": "London",
#                 "sort-name": "London"
#             },
#             "country": "GB",
#             "disambiguation": "60s band from the UK",
#             "id": "9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6",
#             "life-span": {
#                 "begin": "1967",
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "progressive rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "orchestral"
#                 },
#                 {
#                     "count": 1,
#                     "name": "british"
#                 },
#                 {
#                     "count": 1,
#                     "name": "power pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "psychedelic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "soft rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "symphonic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "english"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Nirvana US",
#                     "primary": null,
#                     "sort-name": "Nirvana US",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "a640b45c-c173-49b1-8030-973603e895b5",
#                 "name": "Aberdeen",
#                 "sort-name": "Aberdeen"
#             },
#             "country": "US",
#             "disambiguation": "90s US grunge band",
#             "id": "5b11f4ce-a62d-471e-81fc-a69a8278c7da",
#             "life-span": {
#                 "begin": "1988-01",
#                 "end": "1994-04-05",
#                 "ended": true
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 9,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 4,
#                     "name": "alternative rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "90s"
#                 },
#                 {
#                     "count": 1,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 5,
#                     "name": "american"
#                 },
#                 {
#                     "count": 1,
#                     "name": "seattle"
#                 },
#                 {
#                     "count": 14,
#                     "name": "grunge"
#                 },
#                 {
#                     "count": 0,
#                     "name": "band"
#                 },
#                 {
#                     "count": 1,
#                     "name": "usa"
#                 },
#                 {
#                     "count": 0,
#                     "name": "alternative"
#                 },
#                 {
#                     "count": 0,
#                     "name": "am\u00e9ricain"
#                 },
#                 {
#                     "count": 0,
#                     "name": "legendary"
#                 },
#                 {
#                     "count": 1,
#                     "name": "acoustic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "noise rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "90"
#                 },
#                 {
#                     "count": 0,
#                     "name": "northwest"
#                 },
#                 {
#                     "count": 0,
#                     "name": "rock and indie"
#                 },
#                 {
#                     "count": 0,
#                     "name": "united states"
#                 },
#                 {
#                     "count": 0,
#                     "name": "nirvana"
#                 },
#                 {
#                     "count": 0,
#                     "name": "kurt cobain"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "id": "c3a64a25-251b-4d03-afba-1471440245b8",
#             "life-span": {
#                 "begin": "2009",
#                 "ended": null
#             },
#             "name": "Approaching Nirvana",
#             "score": "62",
#             "sort-name": "Approaching Nirvana",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Nirvana",
#                     "primary": null,
#                     "sort-name": "Nirvana",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Prophet 2002",
#                     "primary": null,
#                     "sort-name": "Prophet 2002",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "23d10872-f5ae-3f0c-bf55-332788a16ecb",
#                 "name": "Sweden",
#                 "sort-name": "Sweden"
#             },
#             "country": "SE",
#             "disambiguation": "Swedish death metal band",
#             "id": "f2dfdff9-3862-4be0-bf85-9c833fa3059e",
#             "life-span": {
#                 "begin": "1988",
#                 "ended": null
#             },
#             "name": "Nirvana 2002",
#             "score": "62",
#             "sort-name": "Nirvana 2002",
#             "type": "Group"
#         },
#         {
#             "id": "329c04ae-3b73-4ca3-996f-75608ab1befb",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Singh",
#             "score": "62",
#             "sort-name": "Singh, Nirvana",
#             "type": "Person"
#         },
#         {
#             "id": "b305320e-c158-43f4-b5be-4450e2f99a32",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "El Nirvana",
#             "score": "62",
#             "sort-name": "Nirvana, El"
#         },
#         {
#             "id": "86f9ae24-ba2a-4d55-9275-0b89b85f6e3a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Weed Nirvana",
#             "score": "62",
#             "sort-name": "Weed Nirvana"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "female",
#             "id": "206419e0-3a7a-49ce-8437-4e757767d02b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Savoury",
#             "score": "62",
#             "sort-name": "Savoury, Nirvana",
#             "type": "Person"
#         },
#         {
#             "id": "f58febd3-18de-4371-8d95-4a68d4f79456",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Kelly",
#             "score": "62",
#             "sort-name": "Kelly, Nirvana",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "c621114d-73cc-4832-8afe-f13dc261e5af",
#                 "name": "Gatineau",
#                 "sort-name": "Gatineau"
#             },
#             "begin-area": {
#                 "id": "c621114d-73cc-4832-8afe-f13dc261e5af",
#                 "name": "Gatineau",
#                 "sort-name": "Gatineau"
#             },
#             "id": "02c4e6bb-7b7a-4686-8c23-df01bfd42b0e",
#             "life-span": {
#                 "begin": "2012-04-05",
#                 "ended": null
#             },
#             "name": "Sappy Nirvana Tribute",
#             "score": "50",
#             "sort-name": "Sappy Nirvana Tribute",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "e8ad73e9-9e7f-41c4-a395-6e29260ff1df",
#                 "name": "Graz",
#                 "sort-name": "Graz"
#             },
#             "begin-area": {
#                 "id": "e8ad73e9-9e7f-41c4-a395-6e29260ff1df",
#                 "name": "Graz",
#                 "sort-name": "Graz"
#             },
#             "disambiguation": "Nirvana-Coverband",
#             "id": "46d8dae4-abec-438b-9c62-a3dbb2aaa1b7",
#             "life-span": {
#                 "begin": "2000",
#                 "ended": null
#             },
#             "name": "Nirvana Teen Spirit",
#             "score": "50",
#             "sort-name": "Nirvana Teen Spirit",
#             "type": "Group"
#         },
#         {
#             "id": "bb94730d-22c2-422d-a0a7-fe16a5b3e429",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Attainment of Nirvana",
#             "score": "50",
#             "sort-name": "Attainment of Nirvana, The",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "c920948b-83e3-40b7-8fe9-9ab5abaac55b",
#                 "name": "Houston",
#                 "sort-name": "Houston"
#             },
#             "begin-area": {
#                 "id": "c920948b-83e3-40b7-8fe9-9ab5abaac55b",
#                 "name": "Houston",
#                 "sort-name": "Houston"
#             },
#             "disambiguation": "Nirvana Cover Band",
#             "id": "45eacd92-6857-4faa-9283-023e72a1d4b1",
#             "life-span": {
#                 "begin": "2012",
#                 "ended": null
#             },
#             "name": "The Nirvana Experience",
#             "score": "50",
#             "sort-name": "The Nirvana Experience",
#             "type": "Group"
#         },
#         {
#             "id": "e43ad11b-5d29-45ae-90f7-73ac47fb815d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "smells like nirvana",
#             "score": "50",
#             "sort-name": "smells like nirvana"
#         },
#         {
#             "id": "e1388435-f80d-434a-9980-f1c9f5aa9b90",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Sitar & String Group",
#             "score": "43",
#             "sort-name": "Nirvana Sitar & String Group"
#         }
#     ],
#     "count": 18,
#     "created": "2017-08-29T21:21:27.891Z",
#     "offset": 0
# }

# %%
# Isolate information from the 4th band returned (index 3)
print( "\nARTIST:", pretty_print(results["artists"][3]))
# Out:
# {
#     "area": {
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom"
#     },
#     "begin-area": {
#         "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#         "name": "London",
#         "sort-name": "London"
#     },
#     "country": "GB",
#     "disambiguation": "60s band from the UK",
#     "id": "9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6",
#     "life-span": {
#         "begin": "1967",
#         "ended": null
#     },
#     "name": "Nirvana",
#     "score": "100",
#     "sort-name": "Nirvana",
#     "tags": [
#         {
#             "count": 1,
#             "name": "rock"
#         },
#         {
#             "count": 1,
#             "name": "pop"
#         },
#         {
#             "count": 1,
#             "name": "progressive rock"
#         },
#         {
#             "count": 1,
#             "name": "orchestral"
#         },
#         {
#             "count": 1,
#             "name": "british"
#         },
#         {
#             "count": 1,
#             "name": "power pop"
#         },
#         {
#             "count": 1,
#             "name": "psychedelic rock"
#         },
#         {
#             "count": 1,
#             "name": "soft rock"
#         },
#         {
#             "count": 1,
#             "name": "symphonic rock"
#         },
#         {
#             "count": 1,
#             "name": "english"
#         }
#     ],
#     "type": "Group"
# }
#
# ARTIST: None

# %%
# Query for releases from that band using the artist_id
artist_id = results["artists"][3]["id"]

# store results in variable
artist_data = query_site(ARTIST_URL, query_type["releases"], artist_id)

# store releases in variable
releases = artist_data["releases"]
# Out:
# requesting http://musicbrainz.org/ws/2/artist/9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6?inc=releases&fmt=json .....

# %%
# print infro about releases from specified band
print( "\nONE RELEASE:",pretty_print(releases[0], indent=2))
# Out:
# {
#   "barcode": null,
#   "country": "GB",
#   "date": "1969",
#   "disambiguation": "",
#   "id": "0b44cb36-550a-491d-bfd9-8751271f9de7",
#   "packaging": null,
#   "packaging-id": null,
#   "quality": "normal",
#   "release-events": [
#     {
#       "area": {
#         "disambiguation": "",
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "iso-3166-1-codes": [
#           "GB"
#         ],
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom"
#       },
#       "date": "1969"
#     }
#   ],
#   "status": "Official",
#   "status-id": "4e304316-386d-3409-af2e-78857eec5cfe",
#   "text-representation": {
#     "language": "eng",
#     "script": "Latn"
#   },
#   "title": "To Markos III"
# }
#
# ONE RELEASE: None

# %%
# get titles of all releases + print them out
release_titles = [r["title"] for r in releases]

print( "\nALL TITLES:\n")
for t in release_titles:
      print(t)
# Out:
# ALL TITLES:
#
# To Markos III
# Travelling on a Cloud
# Songs Of Love And Praise
# Songs of Love and Praise
# Songs of Love and Praise
# Secret Theatre
# The Story of Simon Simopath
# Me And My Friend
# All of Us
# The Story of Simon Simopath
# To Markos III
# Chemistry
# The Story of Simon Simopath
# Local Anaesthetic
# Orange & Blue
# Pentecost Hotel
# Black Flower
# All of Us
# Local Anaesthetic

# %%
# Query for info in the database about bands named Between the Buried and Me
results = query_by_name(ARTIST_URL, query_type["simple"], "Between the Buried and Me")
pretty_print(results)
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?fmt=json&query=artist%3ABetween+the+Buried+and+Me .....
#
# {
#     "artists": [
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "3f8828b9-ba93-4604-9b92-1f616fa1abd1",
#                 "name": "Raleigh",
#                 "sort-name": "Raleigh"
#             },
#             "country": "US",
#             "id": "1870fb43-50f1-4660-a879-bb596d1519b6",
#             "life-span": {
#                 "begin": "2000",
#                 "ended": null
#             },
#             "name": "Between the Buried and Me",
#             "score": "100",
#             "sort-name": "Between the Buried and Me",
#             "tags": [
#                 {
#                     "count": 2,
#                     "name": "progressive metal"
#                 },
#                 {
#                     "count": 1,
#                     "name": "metal"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "b4e9352c-8edf-4911-8fa3-e852afa30501",
#                 "name": "Melbourne",
#                 "sort-name": "Melbourne"
#             },
#             "id": "a4dbddc8-a08d-424e-b0b7-69b423681190",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Between You & Me",
#             "score": "27",
#             "sort-name": "Between You & Me",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "Small german band",
#             "id": "3f5f3ac6-8754-4537-93d8-92fd421068ff",
#             "life-span": {
#                 "begin": "2007",
#                 "ended": null
#             },
#             "name": "Buried in Between",
#             "score": "23",
#             "sort-name": "Buried in Between",
#             "type": "Group"
#         },
#         {
#             "id": "8183b6b0-9c55-4348-895b-97f3167f99db",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Organ, the Dance Band & Me",
#             "score": "22",
#             "sort-name": "The Organ, the Dance Band & Me",
#             "type": "Group"
#         },
#         {
#             "id": "259f0768-68c6-4fa8-8785-420e1df61df4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Tiger & Me",
#             "score": "22",
#             "sort-name": "Tiger & Me, The",
#             "type": "Group"
#         },
#         {
#             "id": "48c90724-444a-489a-9663-89b3863de67f",
#             "life-span": {
#                 "begin": "1966",
#                 "end": "1967-01",
#                 "ended": true
#             },
#             "name": "Me And The Others",
#             "score": "22",
#             "sort-name": "Me And The Others",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "6743d351-6f37-3049-9724-5041161fff4d",
#                 "name": "Norway",
#                 "sort-name": "Norway"
#             },
#             "country": "NO",
#             "id": "24a73584-1c5f-480c-b402-5bd1303ea058",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Captain & Me",
#             "score": "22",
#             "sort-name": "Captain, The & Me",
#             "type": "Group"
#         },
#         {
#             "id": "4a2c9a57-df7a-4106-a1a6-8ffa2fe3ef1a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Me & The Rest",
#             "score": "22",
#             "sort-name": "Me & Rest, The",
#             "type": "Group"
#         },
#         {
#             "id": "2ba892b9-830a-4c7c-b3d5-39f25df0eda7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Me and the Boys",
#             "score": "22",
#             "sort-name": "Me and the Boys",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "id": "56ce78a0-9eb4-4a7c-93c3-eba1cdecad91",
#             "life-span": {
#                 "begin": "2010-07-01",
#                 "ended": null
#             },
#             "name": "Me and the Mountain",
#             "score": "22",
#             "sort-name": "Me and the Mountain",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "country": "DE",
#             "id": "964cb44d-55f0-4bf4-98b6-fa38d91150e0",
#             "life-span": {
#                 "end": "1985",
#                 "ended": true
#             },
#             "name": "Me & The Heat",
#             "score": "22",
#             "sort-name": "Me & The Heat",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "new wave"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "id": "0109354e-34f2-415a-9c68-d1c704caf409",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Me & The Bees",
#             "score": "22",
#             "sort-name": "Me & Bees, The"
#         },
#         {
#             "area": {
#                 "id": "0573177b-9ff9-4643-80bc-ed2513419267",
#                 "name": "Ohio",
#                 "sort-name": "Ohio"
#             },
#             "disambiguation": "60's Ohio garage rock band",
#             "id": "e46fc9c6-29fd-4105-89b4-f26be0b24f77",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Me and The Guys",
#             "score": "22",
#             "sort-name": "Me and Guys, The",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "Rock band from Switzerland.",
#             "id": "9f277c72-5bd1-4035-9430-3e7b6a59dd7a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Me and the Rest",
#             "score": "22",
#             "sort-name": "Me and the Rest",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "You Me & The Atom Bomb",
#                     "primary": null,
#                     "sort-name": "You Me & The Atom Bomb",
#                     "type": null
#                 }
#             ],
#             "id": "721df567-d290-4c7c-a663-d3896e0de653",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "You Me and the Atom Bomb",
#             "score": "21",
#             "sort-name": "You Me and the Atom Bomb"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Gimme Gimmees",
#                     "primary": null,
#                     "sort-name": "Gimme Gimmees",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Me First and the Gimme Gimmies",
#                     "primary": null,
#                     "sort-name": "Me First and the Gimme Gimmies",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Me First And The Gimmie Gimmes",
#                     "primary": null,
#                     "sort-name": "Me First And The Gimmie Gimmes",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Me First and the Gimmie Gimmies",
#                     "primary": null,
#                     "sort-name": "Me First and the Gimmie Gimmies",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Me First & The Gimme Gimmes",
#                     "primary": null,
#                     "sort-name": "Me First & The Gimme Gimmes",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "83f22bb6-4631-443c-bace-9fae8540362a",
#                 "name": "San Francisco",
#                 "sort-name": "San Francisco"
#             },
#             "country": "US",
#             "id": "9478e346-7c52-4780-9555-3d1577f0b905",
#             "life-span": {
#                 "begin": "1995",
#                 "ended": null
#             },
#             "name": "Me First and the Gimme Gimmes",
#             "score": "21",
#             "sort-name": "Me First and the Gimme Gimmes",
#             "tags": [
#                 {
#                     "count": 3,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "punk rock"
#                 },
#                 {
#                     "count": 2,
#                     "name": "covers"
#                 },
#                 {
#                     "count": 1,
#                     "name": "usa"
#                 },
#                 {
#                     "count": 2,
#                     "name": "punk covers"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "id": "faa4d801-f28d-40da-a16a-1a8c1d60c3e1",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Dead and Buried",
#             "score": "21",
#             "sort-name": "Dead and Buried"
#         },
#         {
#             "id": "f1539cee-7569-4519-84de-ee6cfb9f1f0c",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Buried Heart Project",
#             "score": "20",
#             "sort-name": "Buried Heart Project, The"
#         },
#         {
#             "id": "9ef8ab91-4ad5-4750-b71e-91e4a9daf1e3",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Buried in the Backyard",
#             "score": "20",
#             "sort-name": "Buried in the Backyard"
#         },
#         {
#             "id": "d8b95302-2a37-444e-95bd-a2f76bae8972",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "From The Buried",
#             "score": "20",
#             "sort-name": "From The Buried",
#             "type": "Group"
#         },
#         {
#             "id": "db8b51f3-09e6-4640-be8b-5540eb34d5fa",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Buried Beds",
#             "score": "20",
#             "sort-name": "Buried Beds, The"
#         },
#         {
#             "id": "456eeda3-e477-4dcf-8ea7-e7a2547c72ee",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "You Me and The People",
#             "score": "20",
#             "sort-name": "You Me and The People"
#         },
#         {
#             "id": "d755c0d5-365f-4058-8b8f-eafd085935cd",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Me and the Dirty Girl",
#             "score": "20",
#             "sort-name": "Me and the Dirty Girl"
#         },
#         {
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "country": "DE",
#             "id": "49625899-1669-4945-a3f1-299d8bc09d6d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Me and The White Tiger",
#             "score": "20",
#             "sort-name": "Me and The White Tiger",
#             "type": "Group"
#         },
#         {
#             "id": "5e29b701-6ca9-46e3-9736-1241d8f2dc0a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Me and The Other Guy",
#             "score": "20",
#             "sort-name": "Me and The Other Guy"
#         }
#     ],
#     "count": 104896,
#     "created": "2017-08-29T21:21:27.891Z",
#     "offset": 0
# }

# %%
# Query for releases from that band using the artist_id
artist_id = results["artists"][0]["id"]

# store results in variable
artist_data = query_site(ARTIST_URL, query_type["releases"], artist_id)

# store releases in variable
releases = artist_data["releases"]
# Out:
# requesting http://musicbrainz.org/ws/2/artist/1870fb43-50f1-4660-a879-bb596d1519b6?inc=releases&fmt=json .....

# %%
# get titles of all releases + print them out
release_titles = [r["title"] for r in releases]

print( "\nALL TITLES:\n")
for t in release_titles:
      print(t)
# Out:
# ALL TITLES:
#
# The Anatomy Of
# Between the Buried and Me
# The Parallax: Hypersleep Dialogues
# Between the Buried and Me
# Alaska
# Between the Buried and Me
# Best of Between the Buried and Me
# The Silent Circus
# The Parallax II: Future Sequence
# Colors_Live
# Snapshot
# Demo
# The Great Misdirect
# Between the Buried and Me
# The Great Misdirect - Album Sampler
# The Silent Circus
# Alaska (instrumental)
# The Parallax: Hypersleep Dialogues
# The Great Misdirect
# The Silent Circus
# Colors
# The Parallax I & II Limited Box Set
# The Parallax II: Future Sequence
# Astral Bodies Live
# The Parallax II: Future Sequence

# %% [markdown]
# <h1> QUIZ </h1>

# %% [markdown]
# <h3> How many bands are named First Aid Kit? </h3>

# %%
## query first aid kit from site
quiz_results = query_by_name(ARTIST_URL, query_type["simple"], "First Aid Kit")
pretty_print(quiz_results)
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?fmt=json&query=artist%3AFirst+Aid+Kit .....
#
# {
#     "artists": [
#         {
#             "area": {
#                 "id": "471c46a7-afc5-31c4-923c-d0444f5053a4",
#                 "name": "Spain",
#                 "sort-name": "Spain"
#             },
#             "begin-area": {
#                 "id": "12c3b82e-fcab-4219-9bd5-792089d8280e",
#                 "name": "Barcelona",
#                 "sort-name": "Barcelona"
#             },
#             "country": "ES",
#             "disambiguation": "Spanish indie electronic band",
#             "id": "e4466078-fb0f-4899-98a2-7c7dfeb14714",
#             "life-span": {
#                 "begin": "2004",
#                 "ended": null
#             },
#             "name": "First Aid Kit",
#             "score": "100",
#             "sort-name": "First Aid Kit",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "23d10872-f5ae-3f0c-bf55-332788a16ecb",
#                 "name": "Sweden",
#                 "sort-name": "Sweden"
#             },
#             "begin-area": {
#                 "id": "1127ddc2-eab3-4662-8718-6adbdeea3b10",
#                 "name": "Stockholm",
#                 "sort-name": "Stockholm"
#             },
#             "country": "SE",
#             "disambiguation": "Swedish folk band",
#             "id": "373faa02-74d7-4b1d-9b47-7574ad510f8d",
#             "life-span": {
#                 "begin": "2007",
#                 "ended": null
#             },
#             "name": "First Aid Kit",
#             "score": "100",
#             "sort-name": "First Aid Kit",
#             "tags": [
#                 {
#                     "count": 0,
#                     "name": "remember"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "ko",
#                     "name": "\uc5d0\uc774\ub4dc",
#                     "primary": null,
#                     "sort-name": "\uc5d0\uc774\ub4dc",
#                     "type": "Artist name"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "en",
#                     "name": "AID",
#                     "primary": null,
#                     "sort-name": "AID",
#                     "type": "Artist name"
#                 }
#             ],
#             "area": {
#                 "id": "b9f7d640-46e8-313e-b158-ded6d18593b3",
#                 "name": "South Korea",
#                 "sort-name": "South Korea"
#             },
#             "country": "KR",
#             "disambiguation": "Korean producer",
#             "gender": "male",
#             "id": "3266ea60-5690-464a-ae67-27c8681a9723",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "FIRST AID",
#             "score": "50",
#             "sort-name": "FIRST AID",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "1f1fc3a4-9500-39b8-9f10-f0a465557eef",
#                 "name": "Russia",
#                 "sort-name": "Russia"
#             },
#             "country": "RU",
#             "disambiguation": "Russian metal",
#             "id": "5bb6d8b6-dcd8-46e0-84dc-5a0d927c8475",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "48",
#             "sort-name": "First Aid",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "caac77d1-a5c8-3e6e-8e27-90b44dcc1446",
#                 "name": "Austria",
#                 "sort-name": "Austria"
#             },
#             "begin-area": {
#                 "id": "caac77d1-a5c8-3e6e-8e27-90b44dcc1446",
#                 "name": "Austria",
#                 "sort-name": "Austria"
#             },
#             "country": "AT",
#             "disambiguation": "Austrian Rockband",
#             "id": "268d84a6-620a-4a87-b467-d2236f9264b6",
#             "life-span": {
#                 "begin": "2000",
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "48",
#             "sort-name": "First Aid",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "e1c1215f-dcc0-35b4-b840-d2ca2151593b",
#                 "name": "Estonia",
#                 "sort-name": "Estonia"
#             },
#             "country": "EE",
#             "disambiguation": "Estonian band",
#             "id": "93d871dc-38f4-442e-8292-db7d670794ea",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "48",
#             "sort-name": "First Aid",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "featured on \u201cStay the Night\u201d by Kuts & Mouse",
#             "id": "3dae6add-712f-4592-8ece-da15d02ec943",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "48",
#             "sort-name": "First Aid"
#         },
#         {
#             "id": "612e0dcb-2b47-4feb-ad34-6259433de61d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid 4 Souls",
#             "score": "39",
#             "sort-name": "First Aid 4 Souls"
#         },
#         {
#             "id": "c3eee377-bfd1-49fa-906c-7562db86a45d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The First Aid",
#             "score": "39",
#             "sort-name": "First Aid, The",
#             "type": "Group"
#         },
#         {
#             "id": "fbf39528-f7a1-491d-a5d4-94df61f88ad9",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "DJ First Aid",
#             "score": "39",
#             "sort-name": "DJ First Aid"
#         },
#         {
#             "disambiguation": "Germany",
#             "id": "97b182ff-5f86-451c-b2b4-27840b7d512a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "35",
#             "sort-name": "First Aid"
#         },
#         {
#             "id": "ae609ba9-5df4-4ef4-aa4a-18805397ef24",
#             "life-span": {
#                 "begin": "1990",
#                 "ended": null
#             },
#             "name": "A\u00edd",
#             "score": "31",
#             "sort-name": "A\u00edd",
#             "type": "Person"
#         },
#         {
#             "id": "ed6459f1-257f-433a-85c1-970b2fbbc0af",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "K.I.T.",
#             "score": "27",
#             "sort-name": "K.I.T."
#         },
#         {
#             "area": {
#                 "id": "08310658-51eb-3801-80de-5a0739207115",
#                 "name": "France",
#                 "sort-name": "France"
#             },
#             "country": "FR",
#             "disambiguation": "Paris electro-pop trio",
#             "id": "2d1caf76-ccd5-4cbc-a1b0-c36186c81c15",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "KIT",
#             "score": "27",
#             "sort-name": "KIT",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "song \"Piss die Wand an\" feat. Officer Bronco & Brad Pitch",
#             "id": "2b1895a9-6906-4700-b0ed-98561cb58474",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Kit",
#             "score": "27",
#             "sort-name": "Kit",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "40d758a4-b7c2-40f3-b439-5efbd2a3b038",
#                 "name": "Bristol",
#                 "sort-name": "Bristol"
#             },
#             "disambiguation": "Kit Fegradoe - UK ambient/electronic artist",
#             "gender": "male",
#             "id": "b199b386-e0b1-4137-9faa-c9bc09b1eda4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Kit",
#             "score": "27",
#             "sort-name": "Kit",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "c998ef9b-8656-45f3-ba70-8d8c15a33a29",
#                 "name": "A\u00e7ores",
#                 "sort-name": "A\u00e7ores"
#             },
#             "disambiguation": "Jo\u00e3o Martins, Azorean artist",
#             "gender": "male",
#             "id": "a710d032-28fd-4657-9ae7-3f2a7a53a94f",
#             "life-span": {
#                 "end": "2016-02",
#                 "ended": true
#             },
#             "name": "Kit",
#             "score": "27",
#             "sort-name": "Kit",
#             "type": "Person"
#         },
#         {
#             "disambiguation": "George Chen, Vice Cooler",
#             "id": "ede72177-00cd-4ddf-b04b-1b7c754fed79",
#             "life-span": {
#                 "begin": "2003",
#                 "ended": null
#             },
#             "name": "KIT",
#             "score": "26",
#             "sort-name": "KIT",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Ferry Aid (Zeebrugge)",
#                     "primary": null,
#                     "sort-name": "Ferry Aid (Zeebrugge)",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "id": "590233d0-5ab2-4a67-8f43-a647c2100bdc",
#             "life-span": {
#                 "begin": "1987",
#                 "end": "1987",
#                 "ended": true
#             },
#             "name": "Ferry Aid",
#             "score": "20",
#             "sort-name": "Ferry Aid",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "1127ddc2-eab3-4662-8718-6adbdeea3b10",
#                 "name": "Stockholm",
#                 "sort-name": "Stockholm"
#             },
#             "begin-area": {
#                 "id": "1127ddc2-eab3-4662-8718-6adbdeea3b10",
#                 "name": "Stockholm",
#                 "sort-name": "Stockholm"
#             },
#             "id": "68114f1c-2147-4c9f-a6de-8c2077b54dca",
#             "life-span": {
#                 "begin": "2016-06-23",
#                 "ended": null
#             },
#             "name": "Lucifer's Aid",
#             "score": "20",
#             "sort-name": "Lucifer's Aid"
#         },
#         {
#             "gender": "male",
#             "id": "d8e4fd9f-0a1b-4dbe-9ea6-8352d885fd84",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Peter Aid",
#             "score": "19",
#             "sort-name": "Aid, Peter",
#             "type": "Person"
#         },
#         {
#             "id": "375093c9-b20a-4955-80d1-e84fbacf4a6b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Kool Aid",
#             "score": "19",
#             "sort-name": "Kool Aid"
#         },
#         {
#             "area": {
#                 "id": "71bbafaa-e825-3e15-8ca9-017dcad1748b",
#                 "name": "Canada",
#                 "sort-name": "Canada"
#             },
#             "begin-area": {
#                 "id": "6ccc62d1-bdd8-4f08-8fae-bfaa5310e5ef",
#                 "name": "Vancouver",
#                 "sort-name": "Vancouver"
#             },
#             "country": "CA",
#             "id": "d2559845-4898-458e-aacf-6392ef92dc19",
#             "life-span": {
#                 "begin": "2004",
#                 "end": "2004",
#                 "ended": true
#             },
#             "name": "Mint-Aid",
#             "score": "19",
#             "sort-name": "Mint-Aid",
#             "type": "Group"
#         },
#         {
#             "id": "7fe6ce13-78e4-4dc0-9820-aa2f4acd844a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Punk Aid",
#             "score": "19",
#             "sort-name": "Punk Aid"
#         },
#         {
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "country": "DE",
#             "id": "0fb5fbc3-70ad-4a6d-a3f7-4eaa800b0556",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Dance Aid",
#             "score": "19",
#             "sort-name": "Dance Aid",
#             "type": "Group"
#         }
#     ],
#     "count": 479,
#     "created": "2017-08-29T21:21:27.891Z",
#     "offset": 0
# }

# %%
## check name
quiz_results['artists'][0]['name']
# Out:
# 'First Aid Kit'

# %%
## initialize variables to store counts
first_aid_kit_count = 0;
i = 0;

## for each artist in the results
while i <= len(quiz_results['artists']) - 1:
    ## if they're name is First Aid Kit, count the,
    if quiz_results['artists'][i]['name'].lower() == 'first aid kit':
        #print(quiz_results['artists'][i]['name'])
        first_aid_kit_count += 1
    i += 1

print(first_aid_kit_count)
# Out:
# 2

# %% [markdown]
# <h3> What is the begin-area name for Queen? </h3>

# %%
## query Queen
queen_result = query_by_name(ARTIST_URL, query_type["simple"], "Queen")
pretty_print(queen_result)
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?fmt=json&query=artist%3AQueen .....
#
# {
#     "artists": [
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Queen",
#                     "primary": null,
#                     "sort-name": "Queen",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "2db42837-c832-3c27-b4a3-08198f75693c",
#                 "name": "Japan",
#                 "sort-name": "Japan"
#             },
#             "country": "JP",
#             "disambiguation": "character, voiced by \u677f\u91ce\u53cb\u7f8e / Itano Tomomi",
#             "gender": "female",
#             "id": "420ca290-76c5-41af-999e-564d7c71f1a7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen",
#             "score": "100",
#             "sort-name": "Queen",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "related-akb48"
#                 },
#                 {
#                     "count": 1,
#                     "name": "kamen rider w"
#                 }
#             ],
#             "type": "Character"
#         },
#         {
#             "disambiguation": "US rapper",
#             "id": "5eecaf18-02ec-47af-a4f2-7831db373419",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen",
#             "score": "100",
#             "sort-name": "Queen"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": "2011",
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Queen + Adam Lambert",
#                     "primary": null,
#                     "sort-name": "Queen + Adam Lambert",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "name": "London",
#                 "sort-name": "London"
#             },
#             "country": "GB",
#             "disambiguation": "UK rock group",
#             "id": "0383dadf-2a4e-4d10-a46a-e9e041da8eb3",
#             "life-span": {
#                 "begin": "1970-06-27",
#                 "ended": null
#             },
#             "name": "Queen",
#             "score": "100",
#             "sort-name": "Queen",
#             "tags": [
#                 {
#                     "count": 11,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "progressive rock"
#                 },
#                 {
#                     "count": -2,
#                     "name": "70s"
#                 },
#                 {
#                     "count": -2,
#                     "name": "80s"
#                 },
#                 {
#                     "count": -2,
#                     "name": "90s"
#                 },
#                 {
#                     "count": -1,
#                     "name": "pop-rock"
#                 },
#                 {
#                     "count": 4,
#                     "name": "british"
#                 },
#                 {
#                     "count": 0,
#                     "name": "uk"
#                 },
#                 {
#                     "count": 0,
#                     "name": "band"
#                 },
#                 {
#                     "count": 3,
#                     "name": "hard rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "britannique"
#                 },
#                 {
#                     "count": 0,
#                     "name": "disco"
#                 },
#                 {
#                     "count": 1,
#                     "name": "glam rock"
#                 },
#                 {
#                     "count": -1,
#                     "name": "queen family"
#                 },
#                 {
#                     "count": 2,
#                     "name": "art rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "english"
#                 },
#                 {
#                     "count": 0,
#                     "name": "united kingdom"
#                 },
#                 {
#                     "count": -1,
#                     "name": "queen"
#                 },
#                 {
#                     "count": -1,
#                     "name": "classic pop and rock"
#                 },
#                 {
#                     "count": -1,
#                     "name": "platinum"
#                 },
#                 {
#                     "count": -1,
#                     "name": "pop/rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "80's"
#                 },
#                 {
#                     "count": -1,
#                     "name": "90's"
#                 },
#                 {
#                     "count": 0,
#                     "name": "70's"
#                 },
#                 {
#                     "count": 0,
#                     "name": "langham 1 studio bbc"
#                 },
#                 {
#                     "count": 0,
#                     "name": "kind of magic"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "6195f381-5711-4655-bf7c-75918c04b201",
#                 "name": "Oakland",
#                 "sort-name": "Oakland"
#             },
#             "disambiguation": "Industrial",
#             "id": "7db977b5-9007-4f54-a23d-566f0b4b39dd",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Suicide Queen",
#             "score": "62",
#             "sort-name": "Suicide Queen",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "787abc26-28ce-44f8-a2d1-82d86b5d28a8",
#                 "name": "Pittsburgh",
#                 "sort-name": "Pittsburgh"
#             },
#             "id": "92cb3785-152d-4e1b-bfd5-9572651ad762",
#             "life-span": {
#                 "begin": "2012",
#                 "end": "2013",
#                 "ended": true
#             },
#             "name": "Nomad Queen",
#             "score": "62",
#             "sort-name": "Nomad Queen",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": "2007",
#                     "end-date": "2014-12-17",
#                     "locale": null,
#                     "name": "Demona Mortiss",
#                     "primary": null,
#                     "sort-name": "Demona Mortiss",
#                     "type": "Artist name"
#                 }
#             ],
#             "area": {
#                 "id": "96bbe327-f9cd-42e0-a689-eb9febe1693f",
#                 "name": "Hollywood",
#                 "sort-name": "Hollywood"
#             },
#             "disambiguation": "formerly Demona Mortiss",
#             "id": "ec325188-c5c4-40bc-89c5-1853f3555c06",
#             "life-span": {
#                 "begin": "2007",
#                 "ended": null
#             },
#             "name": "Red Queen",
#             "score": "62",
#             "sort-name": "Red Queen",
#             "type": "Group"
#         },
#         {
#             "gender": "female",
#             "id": "6d8857f3-50ec-4690-aaa2-a9e991157ab8",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Bey",
#             "score": "62",
#             "sort-name": "Bey, Queen",
#             "type": "Person"
#         },
#         {
#             "id": "90953c00-05b8-4a53-9b84-9d12d73450dd",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Caveat",
#             "score": "62",
#             "sort-name": "Queen Caveat",
#             "type": "Group"
#         },
#         {
#             "id": "0709dcb6-f21c-48ff-83a3-84b296a4d049",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Suizide Queen",
#             "score": "62",
#             "sort-name": "Suizide Queen"
#         },
#         {
#             "id": "996dd6a5-3c68-4c86-966e-85adef5c7680",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Aline Queen",
#             "score": "62",
#             "sort-name": "Aline Queen"
#         },
#         {
#             "id": "3577817e-f484-4714-973b-e66c542979d7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Shadow Queen",
#             "score": "62",
#             "sort-name": "Shadow Queen"
#         },
#         {
#             "area": {
#                 "id": "d793f202-faf0-4de8-83e2-9ddfca54a35f",
#                 "name": "Milan",
#                 "sort-name": "Milan"
#             },
#             "begin-area": {
#                 "id": "acae38b3-e987-404e-b4db-c29ad3323c70",
#                 "name": "Gorizia",
#                 "sort-name": "Gorizia"
#             },
#             "id": "e152cff6-4c6f-4853-a140-19a53f7e8a09",
#             "life-span": {
#                 "begin": "2013",
#                 "ended": null
#             },
#             "name": "Lizard Queen",
#             "score": "62",
#             "sort-name": "Lizard Queen",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "progressive metal"
#                 },
#                 {
#                     "count": 1,
#                     "name": "metal"
#                 },
#                 {
#                     "count": 1,
#                     "name": "doom metal"
#                 },
#                 {
#                     "count": 1,
#                     "name": "doom"
#                 },
#                 {
#                     "count": 1,
#                     "name": "stoner metal"
#                 },
#                 {
#                     "count": 1,
#                     "name": "sludge"
#                 },
#                 {
#                     "count": 1,
#                     "name": "stoner"
#                 },
#                 {
#                     "count": 1,
#                     "name": "desert rock"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "gender": "female",
#             "id": "917e6b65-1b9c-449a-878c-88d6ed189c39",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Khadeeja",
#             "score": "62",
#             "sort-name": "Queen Khadeeja",
#             "type": "Person"
#         },
#         {
#             "disambiguation": "Tobacco and Zackey Force Funk",
#             "id": "8afa9a2f-1fe0-4bf7-b8be-c0982c5c855b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Demon Queen",
#             "score": "62",
#             "sort-name": "Demon Queen",
#             "type": "Group"
#         },
#         {
#             "id": "8cf67014-18cc-4a62-941a-ced82412672a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Paula",
#             "score": "62",
#             "sort-name": "Queen Paula"
#         },
#         {
#             "area": {
#                 "id": "023da4a0-acee-3fb1-b91e-5de74ccf787b",
#                 "name": "Kenya",
#                 "sort-name": "Kenya"
#             },
#             "country": "KE",
#             "gender": "female",
#             "id": "a9bede97-1ba2-4985-87cd-96dcc7b47c36",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Jane",
#             "score": "62",
#             "sort-name": "Queen Jane",
#             "type": "Person"
#         },
#         {
#             "id": "5e752cc3-6e64-412e-9ad7-4ee1536b2ed7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen 26",
#             "score": "62",
#             "sort-name": "Queen 26"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "gender": "female",
#             "id": "c3f4e3f6-8eea-41f9-91ff-0a13fa616b3c",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Warrior Queen",
#             "score": "62",
#             "sort-name": "Warrior Queen",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "dubstep"
#                 },
#                 {
#                     "count": 1,
#                     "name": "mc"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "id": "b22cee59-8bfc-42e8-8412-3b9c43ef5de9",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Naughty Queen",
#             "score": "62",
#             "sort-name": "Naughty Queen"
#         },
#         {
#             "id": "9de41fd8-03be-4bbf-a8d6-0909e7bd11b7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Ayacodobae",
#             "score": "62",
#             "sort-name": "Queen Ayacodobae"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "female",
#             "id": "1f8aec46-0cbd-455e-9c57-bfc3cb87a1b4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Esther",
#             "score": "62",
#             "sort-name": "Queen Esther",
#             "type": "Person"
#         },
#         {
#             "id": "0c5d0ae8-6e1d-4775-9d19-5f8a23424fdf",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Elektra",
#             "score": "62",
#             "sort-name": "Queen Elektra"
#         },
#         {
#             "id": "19d4bd22-6cea-4bbf-a559-f82d8e666198",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Border Queen",
#             "score": "62",
#             "sort-name": "Border Queen"
#         },
#         {
#             "id": "ee12fe08-fc61-4229-b9d6-0cd1976fd9c5",
#             "life-span": {
#                 "begin": "1998",
#                 "ended": null
#             },
#             "name": "Queen Bees",
#             "score": "62",
#             "sort-name": "Queen Bees",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "114c14ad-9776-34e9-81b0-6299507f3771",
#                 "name": "Bulgaria",
#                 "sort-name": "Bulgaria"
#             },
#             "country": "BG",
#             "disambiguation": "Bulgarian gothic/power metal band",
#             "id": "d7f334d7-6355-4317-bfd2-41bf577583cd",
#             "life-span": {
#                 "begin": "2001",
#                 "ended": null
#             },
#             "name": "Star Queen",
#             "score": "62",
#             "sort-name": "Star Queen",
#             "type": "Group"
#         }
#     ],
#     "count": 286,
#     "created": "2017-08-29T21:21:27.891Z",
#     "offset": 0
# }

# %%
queen_result['artists'][2]['begin-area']
# Out:
# {'id': 'f03d09b3-39dc-4083-afd6-159e3f0d462f',
#  'name': 'London',
#  'sort-name': 'London'}

# %% [markdown]
# <h3> Spanish Alias for the Beatles </h3>

# %%
## Get JSON for Beatles query
beatles_results = query_by_name(ARTIST_URL, query_type["simple"], "The Beatles")

# Query for releases using the artist_id for Beatles
beatles_artist_id = beatles_results["artists"][0]["id"]

# store results in variable
beatles_data = query_site(ARTIST_URL, query_type["aliases"], beatles_artist_id)

#artist_data['aliases']
i = 0;
while i <= len(beatles_data['aliases']) - 1:
    if beatles_data['aliases'][i]['locale'] == 'es':
        print(beatles_data['aliases'][i]['name'])
    i += 1
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?fmt=json&query=artist%3AThe+Beatles .....
#
# requesting http://musicbrainz.org/ws/2/artist/b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d?inc=aliases&fmt=json .....
#
# Los Beatles

# %% [markdown]
# <h3> Nirvana Disambiguation </h3>

# %%
results = query_by_name(ARTIST_URL, query_type["simple"], "Nirvana")
pretty_print(results)
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?fmt=json&query=artist%3ANirvana .....
#
# {
#     "artists": [
#         {
#             "area": {
#                 "id": "6a264f94-6ff1-30b1-9a81-41f7bfabd616",
#                 "name": "Finland",
#                 "sort-name": "Finland"
#             },
#             "country": "FI",
#             "disambiguation": "Early 1980's Finnish punk band",
#             "id": "85af0709-95db-4fbc-801a-120e9f4766d0",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "finland"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "disambiguation": "founded in 1987 by a Michael Jackson double/imitator",
#             "id": "3aa878c0-224b-41e5-abd1-63be359d2bca",
#             "life-span": {
#                 "begin": "1987",
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana"
#         },
#         {
#             "disambiguation": "French band from Martigues, activ during the 70s.",
#             "id": "c49d69dc-e008-47cf-b5ff-160fafb1fe1f",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "name": "London",
#                 "sort-name": "London"
#             },
#             "country": "GB",
#             "disambiguation": "60s band from the UK",
#             "id": "9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6",
#             "life-span": {
#                 "begin": "1967",
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "progressive rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "orchestral"
#                 },
#                 {
#                     "count": 1,
#                     "name": "british"
#                 },
#                 {
#                     "count": 1,
#                     "name": "power pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "psychedelic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "soft rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "symphonic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "english"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Nirvana US",
#                     "primary": null,
#                     "sort-name": "Nirvana US",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "a640b45c-c173-49b1-8030-973603e895b5",
#                 "name": "Aberdeen",
#                 "sort-name": "Aberdeen"
#             },
#             "country": "US",
#             "disambiguation": "90s US grunge band",
#             "id": "5b11f4ce-a62d-471e-81fc-a69a8278c7da",
#             "life-span": {
#                 "begin": "1988-01",
#                 "end": "1994-04-05",
#                 "ended": true
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 9,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 4,
#                     "name": "alternative rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "90s"
#                 },
#                 {
#                     "count": 1,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 5,
#                     "name": "american"
#                 },
#                 {
#                     "count": 1,
#                     "name": "seattle"
#                 },
#                 {
#                     "count": 14,
#                     "name": "grunge"
#                 },
#                 {
#                     "count": 0,
#                     "name": "band"
#                 },
#                 {
#                     "count": 1,
#                     "name": "usa"
#                 },
#                 {
#                     "count": 0,
#                     "name": "alternative"
#                 },
#                 {
#                     "count": 0,
#                     "name": "am\u00e9ricain"
#                 },
#                 {
#                     "count": 0,
#                     "name": "legendary"
#                 },
#                 {
#                     "count": 1,
#                     "name": "acoustic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "noise rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "90"
#                 },
#                 {
#                     "count": 0,
#                     "name": "northwest"
#                 },
#                 {
#                     "count": 0,
#                     "name": "rock and indie"
#                 },
#                 {
#                     "count": 0,
#                     "name": "united states"
#                 },
#                 {
#                     "count": 0,
#                     "name": "nirvana"
#                 },
#                 {
#                     "count": 0,
#                     "name": "kurt cobain"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "id": "c3a64a25-251b-4d03-afba-1471440245b8",
#             "life-span": {
#                 "begin": "2009",
#                 "ended": null
#             },
#             "name": "Approaching Nirvana",
#             "score": "62",
#             "sort-name": "Approaching Nirvana",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Nirvana",
#                     "primary": null,
#                     "sort-name": "Nirvana",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Prophet 2002",
#                     "primary": null,
#                     "sort-name": "Prophet 2002",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "23d10872-f5ae-3f0c-bf55-332788a16ecb",
#                 "name": "Sweden",
#                 "sort-name": "Sweden"
#             },
#             "country": "SE",
#             "disambiguation": "Swedish death metal band",
#             "id": "f2dfdff9-3862-4be0-bf85-9c833fa3059e",
#             "life-span": {
#                 "begin": "1988",
#                 "ended": null
#             },
#             "name": "Nirvana 2002",
#             "score": "62",
#             "sort-name": "Nirvana 2002",
#             "type": "Group"
#         },
#         {
#             "id": "329c04ae-3b73-4ca3-996f-75608ab1befb",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Singh",
#             "score": "62",
#             "sort-name": "Singh, Nirvana",
#             "type": "Person"
#         },
#         {
#             "id": "b305320e-c158-43f4-b5be-4450e2f99a32",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "El Nirvana",
#             "score": "62",
#             "sort-name": "Nirvana, El"
#         },
#         {
#             "id": "86f9ae24-ba2a-4d55-9275-0b89b85f6e3a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Weed Nirvana",
#             "score": "62",
#             "sort-name": "Weed Nirvana"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "female",
#             "id": "206419e0-3a7a-49ce-8437-4e757767d02b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Savoury",
#             "score": "62",
#             "sort-name": "Savoury, Nirvana",
#             "type": "Person"
#         },
#         {
#             "id": "f58febd3-18de-4371-8d95-4a68d4f79456",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Kelly",
#             "score": "62",
#             "sort-name": "Kelly, Nirvana",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "c621114d-73cc-4832-8afe-f13dc261e5af",
#                 "name": "Gatineau",
#                 "sort-name": "Gatineau"
#             },
#             "begin-area": {
#                 "id": "c621114d-73cc-4832-8afe-f13dc261e5af",
#                 "name": "Gatineau",
#                 "sort-name": "Gatineau"
#             },
#             "id": "02c4e6bb-7b7a-4686-8c23-df01bfd42b0e",
#             "life-span": {
#                 "begin": "2012-04-05",
#                 "ended": null
#             },
#             "name": "Sappy Nirvana Tribute",
#             "score": "50",
#             "sort-name": "Sappy Nirvana Tribute",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "e8ad73e9-9e7f-41c4-a395-6e29260ff1df",
#                 "name": "Graz",
#                 "sort-name": "Graz"
#             },
#             "begin-area": {
#                 "id": "e8ad73e9-9e7f-41c4-a395-6e29260ff1df",
#                 "name": "Graz",
#                 "sort-name": "Graz"
#             },
#             "disambiguation": "Nirvana-Coverband",
#             "id": "46d8dae4-abec-438b-9c62-a3dbb2aaa1b7",
#             "life-span": {
#                 "begin": "2000",
#                 "ended": null
#             },
#             "name": "Nirvana Teen Spirit",
#             "score": "50",
#             "sort-name": "Nirvana Teen Spirit",
#             "type": "Group"
#         },
#         {
#             "id": "bb94730d-22c2-422d-a0a7-fe16a5b3e429",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Attainment of Nirvana",
#             "score": "50",
#             "sort-name": "Attainment of Nirvana, The",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "c920948b-83e3-40b7-8fe9-9ab5abaac55b",
#                 "name": "Houston",
#                 "sort-name": "Houston"
#             },
#             "begin-area": {
#                 "id": "c920948b-83e3-40b7-8fe9-9ab5abaac55b",
#                 "name": "Houston",
#                 "sort-name": "Houston"
#             },
#             "disambiguation": "Nirvana Cover Band",
#             "id": "45eacd92-6857-4faa-9283-023e72a1d4b1",
#             "life-span": {
#                 "begin": "2012",
#                 "ended": null
#             },
#             "name": "The Nirvana Experience",
#             "score": "50",
#             "sort-name": "The Nirvana Experience",
#             "type": "Group"
#         },
#         {
#             "id": "e43ad11b-5d29-45ae-90f7-73ac47fb815d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "smells like nirvana",
#             "score": "50",
#             "sort-name": "smells like nirvana"
#         },
#         {
#             "id": "e1388435-f80d-434a-9980-f1c9f5aa9b90",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Sitar & String Group",
#             "score": "43",
#             "sort-name": "Nirvana Sitar & String Group"
#         }
#     ],
#     "count": 18,
#     "created": "2017-08-29T21:21:27.891Z",
#     "offset": 0
# }

# %% [markdown]
# <h3> When was One Direction Formed? </h3>

# %%
one_direction = query_by_name(ARTIST_URL, query_type["simple"], "One Direction")
pretty_print(one_direction)
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?fmt=json&query=artist%3AOne+Direction .....
#
# {
#     "artists": [
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "name": "London",
#                 "sort-name": "London"
#             },
#             "country": "GB",
#             "id": "1a425bbd-cca4-4b2c-aeb7-71cb176c828a",
#             "life-span": {
#                 "begin": "2010-07",
#                 "ended": null
#             },
#             "name": "One Direction",
#             "score": "100",
#             "sort-name": "One Direction",
#             "tags": [
#                 {
#                     "count": 2,
#                     "name": "pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "power pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "dance-pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "folk pop"
#                 },
#                 {
#                     "count": 2,
#                     "name": "boy band"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "disambiguation": "San Francisco band",
#             "id": "d3479e62-76ac-4aec-9f95-5b222d1e26b1",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Direction",
#             "score": "69",
#             "sort-name": "Direction",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "b2bc1294-77be-4c7b-af93-9868b83b1f34",
#                 "name": "Auckland",
#                 "sort-name": "Auckland"
#             },
#             "disambiguation": "New Zealand punk?",
#             "id": "a234ebb0-0399-4253-baf6-2ae0abc9d8f2",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Direction",
#             "score": "47",
#             "sort-name": "Direction"
#         },
#         {
#             "id": "47813cd0-be78-48ab-802f-1306fc180124",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Loose Direction",
#             "score": "43",
#             "sort-name": "Loose Direction"
#         },
#         {
#             "id": "75fb2c35-4f3a-4145-b948-da871176f039",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Disco Direction",
#             "score": "43",
#             "sort-name": "Disco Direction"
#         },
#         {
#             "id": "9e9d35c3-ce54-4a48-b3ba-4eebdadc1ed8",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Audio Direction",
#             "score": "43",
#             "sort-name": "Audio Direction"
#         },
#         {
#             "id": "6130ddae-22dd-4930-ba0f-6d59f81d3637",
#             "life-span": {
#                 "begin": "2009-08",
#                 "ended": null
#             },
#             "name": "The Direction",
#             "score": "43",
#             "sort-name": "Direction, The",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "disambiguation": "USA punk band",
#             "id": "d554887e-2e17-48f4-8610-624a944a9329",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "No Direction",
#             "score": "43",
#             "sort-name": "No Direction",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "usa"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "id": "355fa6a9-dba2-43b0-bd0f-a9e6dc14c79f",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Direction X",
#             "score": "43",
#             "sort-name": "Direction X",
#             "type": "Group"
#         },
#         {
#             "id": "74c2fbfc-0ced-4f8a-9da6-7df628755757",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "No Direction",
#             "score": "43",
#             "sort-name": "No Direction",
#             "type": "Group"
#         },
#         {
#             "id": "7c4e4dc0-6a0e-4887-b374-0cc57749f563",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Direction Indicator",
#             "score": "43",
#             "sort-name": "Direction Indicator"
#         },
#         {
#             "id": "ce85410c-10e4-4b2e-a878-72483fcf0884",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "7th Direction",
#             "score": "43",
#             "sort-name": "7th Direction"
#         },
#         {
#             "id": "cfd2b787-3656-44ce-9212-9e555b400af5",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "New Direction",
#             "score": "43",
#             "sort-name": "New Direction"
#         },
#         {
#             "id": "2524b4ea-965f-4628-b940-acd0a9210047",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Lost Direction",
#             "score": "43",
#             "sort-name": "Lost Direction"
#         },
#         {
#             "id": "a32cc520-f2e6-4db2-8b61-c7baca599ef5",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Second Direction",
#             "score": "43",
#             "sort-name": "Second Direction"
#         },
#         {
#             "area": {
#                 "id": "ef1b7cc0-cd26-36f4-8ea0-04d9623786c7",
#                 "name": "Netherlands",
#                 "sort-name": "Netherlands"
#             },
#             "begin-area": {
#                 "id": "0b565bc6-05e7-4c3a-bc28-075fabd9a8d0",
#                 "name": "Maastricht",
#                 "sort-name": "Maastricht"
#             },
#             "country": "NL",
#             "id": "574236dc-aa46-4194-8200-6cb039e9ddbd",
#             "life-span": {
#                 "begin": "1989",
#                 "end": "2008",
#                 "ended": true
#             },
#             "name": "Right Direction",
#             "score": "43",
#             "sort-name": "Right Direction",
#             "type": "Group"
#         },
#         {
#             "id": "65cd1bef-0de3-439e-a2fc-a71c308c6359",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "\u9ad8\u67f3\u660c\u884c New Direction",
#             "score": "38",
#             "sort-name": "Masayuki Takayanagi New Direction"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Masayuki \"Jojo\" Takayanagi* & New Direction For The Arts",
#                     "primary": null,
#                     "sort-name": "Masayuki \"Jojo\" Takayanagi* & New Direction For The Arts",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "2db42837-c832-3c27-b4a3-08198f75693c",
#                 "name": "Japan",
#                 "sort-name": "Japan"
#             },
#             "country": "JP",
#             "id": "8367123e-9a2b-4f1a-ad22-52dee85b144a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "New Direction for the Arts",
#             "score": "36",
#             "sort-name": "New Direction for the Arts",
#             "type": "Group"
#         },
#         {
#             "id": "3ccdd708-a6f2-4117-938d-4b23f045cbbb",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The New Transit Direction",
#             "score": "34",
#             "sort-name": "New Transit Direction, The"
#         },
#         {
#             "area": {
#                 "id": "71bbafaa-e825-3e15-8ca9-017dcad1748b",
#                 "name": "Canada",
#                 "sort-name": "Canada"
#             },
#             "country": "CA",
#             "id": "e0027978-441c-4877-b36f-0d2833181a42",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Beat Direction",
#             "score": "34",
#             "sort-name": "Beat Direction, The",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "rock",
#             "id": "dffb4132-bfd1-4c23-8128-31c23d0b6fe9",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Found My Direction",
#             "score": "34",
#             "sort-name": "Found My Direction"
#         },
#         {
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "country": "DE",
#             "disambiguation": "Hardcore/Gabber DJ Team",
#             "id": "06a2966d-95c1-4e20-a4d6-26e15d1d7e69",
#             "life-span": {
#                 "begin": "2010",
#                 "ended": null
#             },
#             "name": "Tensor & Re-Direction",
#             "score": "34",
#             "sort-name": "Tensor & Re-Direction",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "106e0bec-b638-3b37-b731-f53d507dc00e",
#                 "name": "Australia",
#                 "sort-name": "Australia"
#             },
#             "country": "AU",
#             "disambiguation": "Hardcore band from Australia",
#             "id": "6fe5e79d-c29a-4a14-91c2-f2e587cba2dd",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Found My Direction",
#             "score": "34",
#             "sort-name": "Found My Direction",
#             "type": "Group"
#         },
#         {
#             "id": "982461f8-d0e0-44c0-9aa3-9ce9df28c71a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Moving in The Right Direction",
#             "score": "31",
#             "sort-name": "Moving in The Right Direction"
#         },
#         {
#             "disambiguation": "Church choir at Lourdes",
#             "id": "c2485094-3ac9-4632-b8d8-aacae7df3b6f",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Chorale et assembl\u00e9e sous la direction de Jean Zune",
#             "score": "30",
#             "sort-name": "Chorale et assembl\u00e9e sous la direction de Jean Zune"
#         }
#     ],
#     "count": 1791,
#     "created": "2017-08-29T21:21:27.891Z",
#     "offset": 0
# }

# %%
one_direction['artists'][0]['life-span']['begin']
# Out:
# '2010-07'

# %%
one_direction['artists'][0]['area']['name']
# Out:
# 'United Kingdom'

# %%
i = 0;
while i <= len(one_direction['artists']) - 1:
    if one_direction['artists'][i]['area']['name'] == 'United Kingdom':
        print(one_direction['artists'][i]['life-span']['begin'])
    i += 1
# Out:
# 2010-07
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-a935e71036b3> in <module>()
#       1 i = 0;
#       2 while i <= len(one_direction['artists']) - 1:
# ----> 3     if one_direction['artists'][i]['area']['name'] == 'United Kingdom':
#       4         #print(one_direction['aliases'][i]['name'])
#       5         print(one_direction['artists'][i]['life-span']['begin'])
#
# KeyError: 'area'
